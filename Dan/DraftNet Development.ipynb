# %% [markdown]
# # DraftNet Development
# daniel.brooks@alumni.caltech.edu <br>
# July 1, 2019 <br>

# %%
#Preprocessing imports.
import numpy as np
from sklearn import preprocessing
from tqdm import tqdm

import draftsimtools as ds

# %%
#Torch imports.
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.dataset import Dataset

# %% [markdown]
# # Load the Dataset

# %%
# Toggle GPU/CPU mode.
# device = torch.device("cpu")
device = torch.device("cuda:0")

# %%
def create_le(cardnames):
    """Create label encoder for cardnames."""
    le = preprocessing.LabelEncoder()
    le.fit(cardnames)
    return le

def draft_to_matrix(cur_draft, le, pack_size=15):
    """Transform draft from cardname list to one hot encoding."""
    pick_list = [np.append(le.transform(cur_draft[i]), (pack_size-len(x))*[0]) \
                 for i, x in enumerate(cur_draft)]
    pick_matrix = np.int16(pick_list, device=device)
    return pick_matrix

def drafts_to_tensor(drafts, le, pack_size=15):
    """Create tensor of shape (num_drafts, 45, 15)."""
    pick_tensor_list = [draft_to_matrix(d, le) for d in drafts]
    pick_tensor = np.int16(pick_tensor_list, device=device)
    return pick_tensor

#Drafts dataset class.
class DraftDataset(Dataset):
    """Defines a draft dataset in PyTorch."""
    
    def __init__(self, drafts_tensor, le):
        """Initialization.
        """
        self.drafts_tensor = drafts_tensor
        self.le = le
        self.cards_in_set = len(self.le.classes_)
        self.pack_size = int(self.drafts_tensor.shape[1]/3)
        self.draft_size = self.pack_size*3
        
    def __getitem__(self, index):
        """Return a training example.
        """
        #Grab information on current draft.
        pick_num = index % self.draft_size #0-self.pack_size*3-1
        draft_num = int((index - pick_num)/self.draft_size)
        
        #Generate.
        x = self.create_new_x(pick_num, draft_num)
        y = self.create_new_y(pick_num, draft_num)
        return x, y
    
    def create_new_x(self, pick_num, draft_num):
        """Generate x, input, as a row vector.
        0:n     : collection vector
                  x[i]=n -> collection has n copies of card i
        n:2n    : pack vector
                  0 -> card not in pack
                  1 -> card in pack
        Efficiency optimization possible. Iterative adds to numpy array.
        """
        #Initialize collection / cards in pack vector.
        x = np.zeros([self.cards_in_set * 2], dtype = "int16")
        
        #Fill in collection vector excluding current pick (first half).
        for n in self.drafts_tensor[draft_num, :pick_num, 0]:
            x[n] += 1
            
        #Fill in pack vector.
        cards_in_pack =  self.pack_size - pick_num%self.pack_size #Cards in current pack.
        for n in self.drafts_tensor[draft_num, pick_num, :cards_in_pack]:
            x[n + self.cards_in_set] = 1
            
        #Convert to Torch tensor.
        x = torch.Tensor(x)
        return x
    
    def create_new_y(self, pick_num, draft_num, not_in_pack=0.5):
        """Generate y, a target pick row vector.
        Picked card is assigned a value of 1.
        Other cards are assigned a value of 0.
        """
        #Initialize target vector.
        #y = np.array([0] * self.cards_in_set)
        y = np.zeros([self.cards_in_set], dtype = "int16")
            
        #Add picked card.
        y[self.drafts_tensor[draft_num, pick_num, 0]] = 1
        #y = torch.Tensor(y, dtype=torch.int64) # Needed as target.
        y = torch.tensor(y, dtype=torch.int64, device=device) # Needed as target.
        return y
    
    def __len__(self):
        return len(self.drafts_tensor) * self.draft_size

def load_dataset(rating_path1, rating_path2, drafts_path):
    """Create drafts tensor from drafts and set files."""
    # Load the set. inputs
    cur_set = ds.create_set(rating_path1, rating_path2)
    raw_drafts = ds.load_drafts(drafts_path)
    
    # Fix commas. 
    cur_set, raw_drafts = ds.fix_commas(cur_set, raw_drafts)
    
    # Process drafts. 
    drafts = ds.process_drafts(raw_drafts)
    
    # Drop empty elements at end, if present. 
    while len(drafts[-1]) == 0:
        drafts = drafts[:-1]
    
    # Create a label encoder.
    le = create_le(cur_set["Name"].values)
    
    # Create drafts tensor. 
    drafts_tensor = drafts_to_tensor(drafts, le)
    
    # Create a dataset.
    cur_dataset = DraftDataset(drafts_tensor, le)
    
    # Get the tensor
    return cur_dataset, drafts_tensor, cur_set, le

# %%
# Define rating file paths. 
rating_path1 = "data/m19_rating.tsv"
rating_path2 = "data/m19_land_rating.tsv"

# Load data. 
train_data, train_tensor, m19_set, le = load_dataset(rating_path1, rating_path2, "data/subset20000/train.csv")
val_data, val_tensor, m19_set, le = load_dataset(rating_path1, rating_path2, "data/subset20000/val.csv")
#test_data, test_tensor, m19_set, le = load_dataset(rating_path1, rating_path2, "data/subset20000/test.csv")
# Out:
# Processing draft: 0.
# Processing draft: 10000.
# Processing draft: 0.

# %%
def create_set_vector(casting_cost, card_type, rarity, color_vector):
    """
    Returns a one hot encoded card property vector. 
    
    There are 21 binary features:
    
    0. cmc=0
    1. cmc=1
    2. cmc=2
    3. cmc=3
    4. cmc=4
    5. cmc=5
    6. cmc=6
    7. cmc>=7
    8. creature?
    9. common?
    10. uncommon?
    11. rare?
    12. mythic?
    13. colorless?
    14. monocolored?
    15. multicolored?
    16. color1?
    17. color2?
    18. color3?
    19. color4?
    20. color5?
    
    :param casting_cost: integer casting cost of card
    :param card_type: "Creature" or other
    :param rarity": "C", "U", "R", or "M"
    "param color_vector": vector corresponding to colors of card, example: [1,0,0,0,1]
    
    """
    # Initialize set vector.
    v = [0] * 21
    
    # Encode cmc. 
    if casting_cost == 0:
        v[0] = 1
    elif casting_cost == 1:
        v[1] = 1
    elif casting_cost == 2:
        v[2] = 1
    elif casting_cost == 3:
        v[3] = 1
    elif casting_cost == 4:
        v[4] = 1
    elif casting_cost == 5:
        v[5] = 1
    elif casting_cost == 6:
        v[6] = 1
    elif casting_cost >= 7:
        v[7] = 1
    else:
        print("WARNING: Undefined casting cost.")
    
    # Encode type.
    if card_type == "Creature":
        v[8] = 1
        
    # Encode rarity.
    if rarity == "C":
        v[9] = 1
    elif rarity == "U":
        v[10] = 1
    elif rarity == "R":
        v[11] = 1
    elif rarity == "M":
        v[12] = 1
    
    # Process number of colors.
    num_colors = len([c for c in color_vector if c > 0])
    if num_colors == 0:
        v[13] = 1
    elif num_colors == 1:
        v[14] = 1
    elif num_colors >= 2:
        v[15] = 1
    
    # Process card color. 
    if color_vector[0] > 0:
        v[16] = 1
    if color_vector[1] > 0:
        v[17] = 1
    if color_vector[2] > 0:
        v[18] = 1
    if color_vector[3] > 0:
        v[19] = 1
    if color_vector[4] > 0:
        v[20] = 1
    return v

# %%
def cmc_from_string(cmc_string):
    """
    Return an integer converted mana cost from cmc_string. 
    
    Each character adds 1 to cmc. 
    
    :param cmc_string: String or integer representation of cmc. Example: "1UBR".
    :returns: Integer cmc. Example: 4.
    """
    # If int, we are done. 
    if type(cmc_string) is int:
        return cmc_string
    
    # Convert string to integer cmc.
    cmc = 0
    digit_string = ""
    letters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")
    digits = set("1234567890")
        
    for c in cmc_string:        
        if c in letters:
            cmc += 1
        else:
            digit_string += c
    if len(digit_string) > 0:
        cmc += int(digit_string)
    return cmc

# %%
def create_set_tensor(magic_set):
    """
    Returns a set tensor which represents the properties of cards in the set.
    
    There are M features and N cards in the set and the tensor is of size M x N.
    
    The features are documented in the create_set_vector() function. 
    """
    set_list = []
    
    # Requires these names to be present in the set file.
    reduced_set = magic_set[["Name", "Casting Cost 1", "Card Type", "Rarity", "Color Vector"]]
    for index, row in reduced_set.iterrows():
        card_vector = create_set_vector(cmc_from_string(row[1]), row[2], row[3], row[4])
        set_list.append(card_vector)
        
    # set_list is currently N x M list of lists. 
    set_flipped = torch.Tensor(set_list)
    set_tensor = torch.transpose(set_flipped, 0, 1)
    return set_tensor

# %%
# Set tensor.
st = create_set_tensor(m19_set).cuda()
print(st.shape)
# Out:
# torch.Size([21, 285])

# %% [markdown]
# # Define the NN

# %%
#Implement NN.
class DraftNet(nn.Module):
    
    def __init__(self, set_tensor):
        """Placeholder NN. Currently does nothing.
        
        param ss: number of cards in set
        param set_tensor: Mxss set tensor describing the set
        """
        super(DraftNet, self).__init__()
        
        # Load set tensor.
        self.set_tensor = set_tensor
        self.set_tensor_tranpose = torch.transpose(set_tensor, 0, 1)
        self.M, self.ss = self.set_tensor.shape
        self.half_ss = self.ss / 2
        
        # Specify layer sizes. 
        size_in = self.ss + self.M
        #size_in = self.ss
        size1 = self.ss
        size2 = self.ss
        size3 = self.ss
        size4 = self.ss
        size5 = self.ss
        size6 = self.ss
        size7 = self.ss
        size8 = self.ss
        
        self.ns = 0.01
        
        self.bn = nn.BatchNorm1d(self.ss + self.M)
        
        self.linear1 = torch.nn.Linear(size_in, size1)
        self.bn1 = nn.BatchNorm1d(size1)
        self.relu1 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout1 = nn.Dropout(0.5)
        
        self.linear2 = torch.nn.Linear(size1, size2)
        self.bn2 = nn.BatchNorm1d(size2)
        self.relu2 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout2 = nn.Dropout(0.5)
        
        self.linear3 = torch.nn.Linear(size2, size3)
        self.bn3 = nn.BatchNorm1d(size3)
        self.relu3 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout3 = nn.Dropout(0.5)
        
        self.linear4 = torch.nn.Linear(size3, size4)
        self.relu4 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout4 = nn.Dropout(0.5)
        
        self.linear5 = torch.nn.Linear(size3, size5)
        self.relu5 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout5 = nn.Dropout(0.5)
        
        self.linear6 = torch.nn.Linear(size3, size6)
        self.relu6 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout6 = nn.Dropout(0.5)
        
        self.linear7 = torch.nn.Linear(size3, size7)
        self.relu7 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout7 = nn.Dropout(0.5)
        
        self.linear8 = torch.nn.Linear(size3, size8)
        self.relu8 = torch.nn.LeakyReLU(negative_slope = self.ns)
        
        
        #self.sm = torch.nn.Softmax()
                
    def forward(self, x):
        
        collection = x[:, :self.ss]
        
        #collection = self.bn(collection)
        
        pack = x[:, self.ss:]
        
        # Get features from set tensor. 
        features = torch.mm(collection, self.set_tensor_tranpose)
        collection_and_features = torch.cat((collection, features), 1)
        
        collection_and_features = self.bn(collection_and_features)
        
        #y = self.linear1(collection_and_features)
        y = self.linear1(collection_and_features)
        y = self.bn1(y)
        y = self.relu1(y)
        y = self.dropout1(y)
        
        y = self.linear2(y)
        y = self.bn2(y)
        y = self.relu2(y)
        y = self.dropout2(y)
        
        y = self.linear3(y)
        y = self.bn3(y)
        y = self.relu3(y)
        y = self.dropout3(y)

        y = self.linear4(y)
        #y = self.relu4(y)
        #y = self.dropout4(y)
        
        #y = self.linear5(y)
        #y = self.relu5(y)
        #y = self.dropout5(y)
        
        #y = self.linear6(y)
        #y = self.relu6(y)
        #y = self.dropout6(y)
        
        #y = self.linear7(y)
        #y = self.relu7(y)
        #y = self.dropout7(y)
        
        #y = self.linear8(y)
        #y = self.relu8(y)
        
        y = y * pack # Enforce cards in pack only.
        
        return y

#Create NN.
net = DraftNet(st).cuda()
#print(net)

# %% [markdown]
# # Network training

# %%
def train_net(net, dataloader, num_epoch, optimizer):
    """Train the network."""
    net.train()    
    my_count = 0
    for epoch in range(num_epoch):
        
        #Loop over x,y for each dataset.
        running_loss = 0
        for i, data in enumerate(dataloader):
        
            my_count+=1
            if my_count % 10000 == 0:
                print(my_count)
        
            #Get the inputs. Keeps batch size.
            x, y = data
            
            # cuda() is needed for GPU mode. Not sure why.
            x = x.cuda()
            y = y.cuda() # One-hot encoded. 
            
            # Zero parameter gradients between batches.
            optimizer.zero_grad()
        
            #Perform training.
            y_pred = net(x)
            y_integer = torch.argmax(y, 1) # Class indices.
            
            # Use cross entropy loss. 
            loss = torch.nn.CrossEntropyLoss()
            output = loss(y_pred, y_integer)
            output.backward()
            optimizer.step()
                        
            #Print loss data.
            running_loss += output.item()
            step = 1
            if i % len(dataloader) == len(dataloader)-1 and (epoch + 1) % step == 0:
                print('Train Cross-Entropy Loss: %.6f' % (running_loss/len(dataloader)))
                running_loss = 0.0

# %%
# Define dataloaders. 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=100, shuffle=True)
valloader = torch.utils.data.DataLoader(val_data, batch_size=100, shuffle=False)

# %% [markdown]
# # Network validation

# %%
def val_net(net, dataloader):
    """Compute accuracy on validation set."""
    net.eval()
    correct = 0.0
    total = 0.0
    
    with torch.no_grad():
        for i, data in enumerate(dataloader):
        
            #Get the inputs. Keeps batch size.
            x, y = data
            
            # cuda() is needed for GPU mode. Not sure why.
            x = x.cuda()
            y = y.cuda()
            y_integer = torch.argmax(y, 1) # Class indices.
            
            # Compute val loss.
            y_pred = net(x)
            y_pred_integer = torch.argmax(y_pred, 1)
            
            # Compute accuracy. 
            correct += int(sum(y_pred_integer == y_integer))
            total += len(y_integer)
            
    accuracy = correct / total

    print("Validation accuracy:", accuracy, " Total picks:", int(total))

# %%
# Train the network over several epochs - no momentu, from scratch.
run = 0

# Now leave optimizer out here. 
#optimizer = optim.Adam(net.parameters(), lr=0.0001, betas=(0.9, 0.999))
#optimizer = optim.ASGD(net.parameters())
#optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.9)

optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.0)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.98)

ep = 0

for run in range(999999):
    
    ep += 1
    print("Epoch:", ep)
    
    # Train1.
    train_net(net, trainloader, 1, optimizer)
    scheduler.step()
    
    # Validation. 
    val_net(net, valloader)
# Out:
# Epoch: 1
# Train Cross-Entropy Loss: 1.569925
# Validation accuracy: 0.6077377777777778  Total picks: 225000
# Epoch: 2
# Train Cross-Entropy Loss: 1.134533
# Validation accuracy: 0.6163333333333333  Total picks: 225000
# Epoch: 3
# Train Cross-Entropy Loss: 1.101022
# Validation accuracy: 0.6208177777777778  Total picks: 225000
# Epoch: 4
# Train Cross-Entropy Loss: 1.080183
# Validation accuracy: 0.6237333333333334  Total picks: 225000
# Epoch: 5
# Train Cross-Entropy Loss: 1.065954
# Validation accuracy: 0.6260488888888889  Total picks: 225000
# Epoch: 6
# Train Cross-Entropy Loss: 1.057866
# Validation accuracy: 0.6267244444444444  Total picks: 225000
# Epoch: 7
# Train Cross-Entropy Loss: 1.049609
# Validation accuracy: 0.6265644444444445  Total picks: 225000
# Epoch: 8
# Train Cross-Entropy Loss: 1.042938
# Validation accuracy: 0.6283688888888889  Total picks: 225000
# Epoch: 9
# Train Cross-Entropy Loss: 1.037118
# Validation accuracy: 0.6306488888888889  Total picks: 225000
# Epoch: 10
# Train Cross-Entropy Loss: 1.030989
# Validation accuracy: 0.63052  Total picks: 225000
# Epoch: 11
# Train Cross-Entropy Loss: 1.027292
# Validation accuracy: 0.6312133333333333  Total picks: 225000
# Epoch: 12
# Train Cross-Entropy Loss: 1.023453
# Validation accuracy: 0.6310444444444444  Total picks: 225000
# Epoch: 13
# Train Cross-Entropy Loss: 1.019325
# Validation accuracy: 0.6324533333333333  Total picks: 225000
# Epoch: 14
# Train Cross-Entropy Loss: 1.016773
# Validation accuracy: 0.6327422222222222  Total picks: 225000
# Epoch: 15
# Train Cross-Entropy Loss: 1.012720
# Validation accuracy: 0.6338222222222222  Total picks: 225000
# Epoch: 16
# Train Cross-Entropy Loss: 1.009191
# Validation accuracy: 0.6336844444444445  Total picks: 225000
# Epoch: 17
# Train Cross-Entropy Loss: 1.006407
# Validation accuracy: 0.6332888888888889  Total picks: 225000
# Epoch: 18
# Train Cross-Entropy Loss: 1.004675
# Validation accuracy: 0.6343466666666666  Total picks: 225000
# Epoch: 19
# Train Cross-Entropy Loss: 1.003475
# Validation accuracy: 0.6341688888888889  Total picks: 225000
# Epoch: 20
# Train Cross-Entropy Loss: 0.999708
# Validation accuracy: 0.6351066666666667  Total picks: 225000
# Epoch: 21
# Train Cross-Entropy Loss: 0.998590
# Validation accuracy: 0.6357111111111111  Total picks: 225000
# Epoch: 22
# Train Cross-Entropy Loss: 0.995581
# Validation accuracy: 0.6350533333333334  Total picks: 225000
# Epoch: 23
# Train Cross-Entropy Loss: 0.993028
# Validation accuracy: 0.6353333333333333  Total picks: 225000
# Epoch: 24
# Train Cross-Entropy Loss: 0.992825
# Validation accuracy: 0.63544  Total picks: 225000
# Epoch: 25
# Train Cross-Entropy Loss: 0.990282
# Validation accuracy: 0.6352444444444444  Total picks: 225000
# Epoch: 26
# Train Cross-Entropy Loss: 0.987710
# Validation accuracy: 0.6358222222222222  Total picks: 225000
# Epoch: 27
# Train Cross-Entropy Loss: 0.987523
# Validation accuracy: 0.6365288888888889  Total picks: 225000
# Epoch: 28
# Train Cross-Entropy Loss: 0.985128
# Validation accuracy: 0.6367466666666667  Total picks: 225000
# Epoch: 29
# Train Cross-Entropy Loss: 0.984477
# Validation accuracy: 0.63652  Total picks: 225000
# Epoch: 30
# Train Cross-Entropy Loss: 0.982223
# Validation accuracy: 0.63544  Total picks: 225000
# Epoch: 31
# Train Cross-Entropy Loss: 0.980744
# Validation accuracy: 0.6364044444444444  Total picks: 225000
# Epoch: 32
# Train Cross-Entropy Loss: 0.981511
# Validation accuracy: 0.6352088888888889  Total picks: 225000
# Epoch: 33
# Train Cross-Entropy Loss: 0.979575
# Validation accuracy: 0.6369822222222222  Total picks: 225000
# Epoch: 34
# Train Cross-Entropy Loss: 0.978032
# Validation accuracy: 0.6372177777777778  Total picks: 225000
# Epoch: 35
# Train Cross-Entropy Loss: 0.977663
# Validation accuracy: 0.6364755555555556  Total picks: 225000
# Epoch: 36
# Train Cross-Entropy Loss: 0.975323
# Validation accuracy: 0.6360044444444445  Total picks: 225000
# Epoch: 37
# Train Cross-Entropy Loss: 0.975154
# Validation accuracy: 0.6375377777777778  Total picks: 225000
# Epoch: 38
# Train Cross-Entropy Loss: 0.974338
# Validation accuracy: 0.63664  Total picks: 225000
# Epoch: 39
# Train Cross-Entropy Loss: 0.972854
# Validation accuracy: 0.6369422222222222  Total picks: 225000
# Epoch: 40
# Train Cross-Entropy Loss: 0.972303
# Validation accuracy: 0.6369288888888889  Total picks: 225000
# Epoch: 41
# Train Cross-Entropy Loss: 0.971190
# Validation accuracy: 0.6368044444444444  Total picks: 225000
# Epoch: 42
# Train Cross-Entropy Loss: 0.970657
# Validation accuracy: 0.6378  Total picks: 225000
# Epoch: 43
# Train Cross-Entropy Loss: 0.969259
# Validation accuracy: 0.6369466666666667  Total picks: 225000
# Epoch: 44
# Train Cross-Entropy Loss: 0.969404
# Validation accuracy: 0.6372977777777777  Total picks: 225000
# Epoch: 45
# Train Cross-Entropy Loss: 0.968600
# Validation accuracy: 0.6371022222222222  Total picks: 225000
# Epoch: 46
# Train Cross-Entropy Loss: 0.966718
# Validation accuracy: 0.6366888888888889  Total picks: 225000
# Epoch: 47
# Train Cross-Entropy Loss: 0.966406
# Validation accuracy: 0.6374666666666666  Total picks: 225000
# Epoch: 48
# Train Cross-Entropy Loss: 0.965770
# Validation accuracy: 0.6374266666666667  Total picks: 225000
# Epoch: 49
# Train Cross-Entropy Loss: 0.965520
# Validation accuracy: 0.6377466666666667  Total picks: 225000
# Epoch: 50
# Train Cross-Entropy Loss: 0.964231
# Validation accuracy: 0.6374177777777777  Total picks: 225000
# Epoch: 51
# Train Cross-Entropy Loss: 0.963421
# Validation accuracy: 0.63728  Total picks: 225000
# Epoch: 52
# Train Cross-Entropy Loss: 0.962655
# Validation accuracy: 0.6368577777777777  Total picks: 225000
# Epoch: 53
# Train Cross-Entropy Loss: 0.962839
# Validation accuracy: 0.6371288888888889  Total picks: 225000
# Epoch: 54
# Train Cross-Entropy Loss: 0.961545
# Validation accuracy: 0.6380533333333334  Total picks: 225000
# Epoch: 55
# Train Cross-Entropy Loss: 0.960976
# Validation accuracy: 0.6373244444444445  Total picks: 225000
# Epoch: 56
# Train Cross-Entropy Loss: 0.960634
# Validation accuracy: 0.6380622222222222  Total picks: 225000
# Epoch: 57
# Train Cross-Entropy Loss: 0.960610
# Validation accuracy: 0.6371733333333334  Total picks: 225000
# Epoch: 58
# Train Cross-Entropy Loss: 0.960581
# Validation accuracy: 0.6378444444444444  Total picks: 225000
# Epoch: 59
# Train Cross-Entropy Loss: 0.958560
# Validation accuracy: 0.638  Total picks: 225000
# Epoch: 60
# Train Cross-Entropy Loss: 0.958636
# Validation accuracy: 0.6375777777777778  Total picks: 225000
# Epoch: 61
# Train Cross-Entropy Loss: 0.957634
# Validation accuracy: 0.63752  Total picks: 225000
# Epoch: 62
# Train Cross-Entropy Loss: 0.957337
# Validation accuracy: 0.6373066666666667  Total picks: 225000
# Epoch: 63
# Train Cross-Entropy Loss: 0.958264
# Validation accuracy: 0.63804  Total picks: 225000
# Epoch: 64
# Train Cross-Entropy Loss: 0.954904
# Validation accuracy: 0.6382533333333333  Total picks: 225000
# Epoch: 65
# Train Cross-Entropy Loss: 0.956693
# Validation accuracy: 0.6377111111111111  Total picks: 225000
# Epoch: 66
# Train Cross-Entropy Loss: 0.955421
# Validation accuracy: 0.6384888888888889  Total picks: 225000
# Epoch: 67
# Train Cross-Entropy Loss: 0.955319
# Validation accuracy: 0.63772  Total picks: 225000
# Epoch: 68
# Train Cross-Entropy Loss: 0.954767
# Validation accuracy: 0.6379555555555556  Total picks: 225000
# Epoch: 69
# Train Cross-Entropy Loss: 0.955061
# Validation accuracy: 0.6385244444444445  Total picks: 225000
# Epoch: 70
# Train Cross-Entropy Loss: 0.953514
# Validation accuracy: 0.6380311111111111  Total picks: 225000
# Epoch: 71
# Train Cross-Entropy Loss: 0.953654
# Validation accuracy: 0.6380222222222223  Total picks: 225000
# Epoch: 72
# Train Cross-Entropy Loss: 0.953742
# Validation accuracy: 0.6387822222222223  Total picks: 225000
# Epoch: 73
# Train Cross-Entropy Loss: 0.952783
# Validation accuracy: 0.6381066666666667  Total picks: 225000
# Epoch: 74
# Train Cross-Entropy Loss: 0.952549
# Validation accuracy: 0.6382844444444444  Total picks: 225000
# Epoch: 75
# Train Cross-Entropy Loss: 0.951557
# Validation accuracy: 0.6377911111111111  Total picks: 225000
# Epoch: 76
# Train Cross-Entropy Loss: 0.952063
# Validation accuracy: 0.6385155555555555  Total picks: 225000
# Epoch: 77
# Train Cross-Entropy Loss: 0.949988
# Validation accuracy: 0.6380533333333334  Total picks: 225000
# Epoch: 78
# Train Cross-Entropy Loss: 0.951024
# Validation accuracy: 0.6386533333333333  Total picks: 225000
# Epoch: 79
# Train Cross-Entropy Loss: 0.949785
# Validation accuracy: 0.6383466666666666  Total picks: 225000
# Epoch: 80
# Train Cross-Entropy Loss: 0.950264
# Validation accuracy: 0.6386444444444445  Total picks: 225000
# Epoch: 81
# Train Cross-Entropy Loss: 0.948675
# Validation accuracy: 0.6387244444444444  Total picks: 225000
# Epoch: 82
# Train Cross-Entropy Loss: 0.949747
# Validation accuracy: 0.6383066666666667  Total picks: 225000
# Epoch: 83
# Train Cross-Entropy Loss: 0.949027
# Validation accuracy: 0.6379866666666667  Total picks: 225000
# Epoch: 84
# Train Cross-Entropy Loss: 0.948605
# Validation accuracy: 0.6385866666666666  Total picks: 225000
# Epoch: 85
# Train Cross-Entropy Loss: 0.948492
# Validation accuracy: 0.63852  Total picks: 225000
# Epoch: 86
# Train Cross-Entropy Loss: 0.949200
# Validation accuracy: 0.6385377777777778  Total picks: 225000
# Epoch: 87
# Train Cross-Entropy Loss: 0.947401
# Validation accuracy: 0.6384044444444444  Total picks: 225000
# Epoch: 88
# Train Cross-Entropy Loss: 0.947165
# Validation accuracy: 0.6386177777777777  Total picks: 225000
# Epoch: 89
# Train Cross-Entropy Loss: 0.947270
# Validation accuracy: 0.6387422222222222  Total picks: 225000
# Epoch: 90
# Train Cross-Entropy Loss: 0.948100
# Validation accuracy: 0.6383333333333333  Total picks: 225000
# Epoch: 91
# Train Cross-Entropy Loss: 0.946535
# Validation accuracy: 0.6385155555555555  Total picks: 225000
# Epoch: 92
# Train Cross-Entropy Loss: 0.946854
# Validation accuracy: 0.63816  Total picks: 225000
# Epoch: 93
# Train Cross-Entropy Loss: 0.945896
# Validation accuracy: 0.6381555555555556  Total picks: 225000
# Epoch: 94
# Train Cross-Entropy Loss: 0.946184
# Validation accuracy: 0.6381022222222222  Total picks: 225000
# Epoch: 95
# Train Cross-Entropy Loss: 0.945209
# Validation accuracy: 0.6387333333333334  Total picks: 225000
# Epoch: 96
# Train Cross-Entropy Loss: 0.945850
# Validation accuracy: 0.6385777777777778  Total picks: 225000
# Epoch: 97
# Train Cross-Entropy Loss: 0.945605
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 98
# Train Cross-Entropy Loss: 0.945671
# Validation accuracy: 0.6384311111111111  Total picks: 225000
# Epoch: 99
# Train Cross-Entropy Loss: 0.944167
# Validation accuracy: 0.6389466666666667  Total picks: 225000
# Epoch: 100
# Train Cross-Entropy Loss: 0.944333
# Validation accuracy: 0.6386355555555555  Total picks: 225000
# Epoch: 101
# Train Cross-Entropy Loss: 0.945105
# Validation accuracy: 0.6394133333333333  Total picks: 225000
# Epoch: 102
# Train Cross-Entropy Loss: 0.944838
# Validation accuracy: 0.6383555555555556  Total picks: 225000
# Epoch: 103
# Train Cross-Entropy Loss: 0.943294
# Validation accuracy: 0.6389644444444444  Total picks: 225000
# Epoch: 104
# Train Cross-Entropy Loss: 0.943965
# Validation accuracy: 0.6386177777777777  Total picks: 225000
# Epoch: 105
# Train Cross-Entropy Loss: 0.942964
# Validation accuracy: 0.6384444444444445  Total picks: 225000
# Epoch: 106
# Train Cross-Entropy Loss: 0.943588
# Validation accuracy: 0.6383155555555555  Total picks: 225000
# Epoch: 107
# Train Cross-Entropy Loss: 0.942576
# Validation accuracy: 0.6385822222222223  Total picks: 225000
# Epoch: 108
# Train Cross-Entropy Loss: 0.943792
# Validation accuracy: 0.6381866666666667  Total picks: 225000
# Epoch: 109
# Train Cross-Entropy Loss: 0.942826
# Validation accuracy: 0.6387422222222222  Total picks: 225000
# Epoch: 110
# Train Cross-Entropy Loss: 0.943409
# Validation accuracy: 0.6386622222222222  Total picks: 225000
# Epoch: 111
# Train Cross-Entropy Loss: 0.943143
# Validation accuracy: 0.6381688888888889  Total picks: 225000
# Epoch: 112
# Train Cross-Entropy Loss: 0.943533
# Validation accuracy: 0.63848  Total picks: 225000
# Epoch: 113
# Train Cross-Entropy Loss: 0.942756
# Validation accuracy: 0.6391688888888889  Total picks: 225000
# Epoch: 114
# Train Cross-Entropy Loss: 0.942122
# Validation accuracy: 0.6390933333333333  Total picks: 225000
# Epoch: 115
# Train Cross-Entropy Loss: 0.942559
# Validation accuracy: 0.6389822222222222  Total picks: 225000
# Epoch: 116
# Train Cross-Entropy Loss: 0.941365
# Validation accuracy: 0.6390977777777778  Total picks: 225000
# Epoch: 117
# Train Cross-Entropy Loss: 0.942255
# Validation accuracy: 0.6391777777777777  Total picks: 225000
# Epoch: 118
# Train Cross-Entropy Loss: 0.942081
# Validation accuracy: 0.6388844444444445  Total picks: 225000
# Epoch: 119
# Train Cross-Entropy Loss: 0.941198
# Validation accuracy: 0.6386577777777778  Total picks: 225000
# Epoch: 120
# Train Cross-Entropy Loss: 0.941010
# Validation accuracy: 0.6390044444444445  Total picks: 225000
# Epoch: 121
# Train Cross-Entropy Loss: 0.939964
# Validation accuracy: 0.6386088888888889  Total picks: 225000
# Epoch: 122
# Train Cross-Entropy Loss: 0.940597
# Validation accuracy: 0.6389422222222222  Total picks: 225000
# Epoch: 123
# Train Cross-Entropy Loss: 0.941384
# Validation accuracy: 0.6385111111111111  Total picks: 225000
# Epoch: 124
# Train Cross-Entropy Loss: 0.938593
# Validation accuracy: 0.6386488888888889  Total picks: 225000
# Epoch: 125
# Train Cross-Entropy Loss: 0.940299
# Validation accuracy: 0.6384311111111111  Total picks: 225000
# Epoch: 126
# Train Cross-Entropy Loss: 0.940826
# Validation accuracy: 0.63848  Total picks: 225000
# Epoch: 127
# Train Cross-Entropy Loss: 0.939985
# Validation accuracy: 0.6386933333333333  Total picks: 225000
# Epoch: 128
# Train Cross-Entropy Loss: 0.940107
# Validation accuracy: 0.6391155555555555  Total picks: 225000
# Epoch: 129
# Train Cross-Entropy Loss: 0.940062
# Validation accuracy: 0.6388  Total picks: 225000
# Epoch: 130
# Train Cross-Entropy Loss: 0.940064
# Validation accuracy: 0.6389955555555555  Total picks: 225000
# Epoch: 131
# Train Cross-Entropy Loss: 0.938856
# Validation accuracy: 0.63904  Total picks: 225000
# Epoch: 132
# Train Cross-Entropy Loss: 0.939669
# Validation accuracy: 0.6385244444444445  Total picks: 225000
# Epoch: 133
# Train Cross-Entropy Loss: 0.939567
# Validation accuracy: 0.6386844444444445  Total picks: 225000
# Epoch: 134
# Train Cross-Entropy Loss: 0.940575
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 135
# Train Cross-Entropy Loss: 0.939218
# Validation accuracy: 0.63924  Total picks: 225000
# Epoch: 136
# Train Cross-Entropy Loss: 0.939880
# Validation accuracy: 0.6389733333333333  Total picks: 225000
# Epoch: 137
# Train Cross-Entropy Loss: 0.939597
# Validation accuracy: 0.6384622222222223  Total picks: 225000
# Epoch: 138
# Train Cross-Entropy Loss: 0.938319
# Validation accuracy: 0.6383777777777778  Total picks: 225000
# Epoch: 139
# Train Cross-Entropy Loss: 0.938478
# Validation accuracy: 0.6383422222222223  Total picks: 225000
# Epoch: 140
# Train Cross-Entropy Loss: 0.938498
# Validation accuracy: 0.6388  Total picks: 225000
# Epoch: 141
# Train Cross-Entropy Loss: 0.938657
# Validation accuracy: 0.6386711111111111  Total picks: 225000
# Epoch: 142
# Train Cross-Entropy Loss: 0.937782
# Validation accuracy: 0.6389644444444444  Total picks: 225000
# Epoch: 143
# Train Cross-Entropy Loss: 0.939344
# Validation accuracy: 0.6385333333333333  Total picks: 225000
# Epoch: 144
# Train Cross-Entropy Loss: 0.938409
# Validation accuracy: 0.6390888888888889  Total picks: 225000
# Epoch: 145
# Train Cross-Entropy Loss: 0.937824
# Validation accuracy: 0.63904  Total picks: 225000
# Epoch: 146
# Train Cross-Entropy Loss: 0.938256
# Validation accuracy: 0.6387644444444445  Total picks: 225000
# Epoch: 147
# Train Cross-Entropy Loss: 0.938567
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 148
# Train Cross-Entropy Loss: 0.937401
# Validation accuracy: 0.6385866666666666  Total picks: 225000
# Epoch: 149
# Train Cross-Entropy Loss: 0.938060
# Validation accuracy: 0.6390533333333334  Total picks: 225000
# Epoch: 150
# Train Cross-Entropy Loss: 0.938058
# Validation accuracy: 0.6389822222222222  Total picks: 225000
# Epoch: 151
# Train Cross-Entropy Loss: 0.937452
# Validation accuracy: 0.6388133333333333  Total picks: 225000
# Epoch: 152
# Train Cross-Entropy Loss: 0.937496
# Validation accuracy: 0.63864  Total picks: 225000
# Epoch: 153
# Train Cross-Entropy Loss: 0.937874
# Validation accuracy: 0.6388488888888889  Total picks: 225000
# Epoch: 154
# Train Cross-Entropy Loss: 0.937394
# Validation accuracy: 0.6390622222222222  Total picks: 225000
# Epoch: 155
# Train Cross-Entropy Loss: 0.937005
# Validation accuracy: 0.6384844444444444  Total picks: 225000
# Epoch: 156
# Train Cross-Entropy Loss: 0.936946
# Validation accuracy: 0.639  Total picks: 225000
# Epoch: 157
# Train Cross-Entropy Loss: 0.937093
# Validation accuracy: 0.6385777777777778  Total picks: 225000
# Epoch: 158
# Train Cross-Entropy Loss: 0.936350
# Validation accuracy: 0.6385377777777778  Total picks: 225000
# Epoch: 159
# Train Cross-Entropy Loss: 0.936672
# Validation accuracy: 0.6391422222222222  Total picks: 225000
# Epoch: 160
# Train Cross-Entropy Loss: 0.937264
# Validation accuracy: 0.6386088888888889  Total picks: 225000
# Epoch: 161
# Train Cross-Entropy Loss: 0.937133
# Validation accuracy: 0.6384266666666667  Total picks: 225000
# Epoch: 162
# Train Cross-Entropy Loss: 0.936246
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 163
# Train Cross-Entropy Loss: 0.935892
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 164
# Train Cross-Entropy Loss: 0.937334
# Validation accuracy: 0.6388933333333333  Total picks: 225000
# Epoch: 165
# Train Cross-Entropy Loss: 0.935945
# Validation accuracy: 0.6386711111111111  Total picks: 225000
# Epoch: 166
# Train Cross-Entropy Loss: 0.937259
# Validation accuracy: 0.6389733333333333  Total picks: 225000
# Epoch: 167
# Train Cross-Entropy Loss: 0.937292
# Validation accuracy: 0.6387911111111111  Total picks: 225000
# Epoch: 168
# Train Cross-Entropy Loss: 0.936486
# Validation accuracy: 0.6388844444444445  Total picks: 225000
# Epoch: 169
# Train Cross-Entropy Loss: 0.936247
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 170
# Train Cross-Entropy Loss: 0.936815
# Validation accuracy: 0.6388266666666667  Total picks: 225000
# Epoch: 171
# Train Cross-Entropy Loss: 0.936041
# Validation accuracy: 0.6388311111111111  Total picks: 225000
# Epoch: 172
# Train Cross-Entropy Loss: 0.936842
# Validation accuracy: 0.6387555555555555  Total picks: 225000
# Epoch: 173
# Train Cross-Entropy Loss: 0.936491
# Validation accuracy: 0.6386666666666667  Total picks: 225000
# Epoch: 174
# Train Cross-Entropy Loss: 0.936801
# Validation accuracy: 0.6390044444444445  Total picks: 225000
# Epoch: 175
# Train Cross-Entropy Loss: 0.935468
# Validation accuracy: 0.6386711111111111  Total picks: 225000
# Epoch: 176
# Train Cross-Entropy Loss: 0.936521
# Validation accuracy: 0.6387688888888889  Total picks: 225000
# Epoch: 177
# Train Cross-Entropy Loss: 0.935013
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 178
# Train Cross-Entropy Loss: 0.935697
# Validation accuracy: 0.6384533333333333  Total picks: 225000
# Epoch: 179
# Train Cross-Entropy Loss: 0.935487
# Validation accuracy: 0.6388488888888889  Total picks: 225000
# Epoch: 180
# Train Cross-Entropy Loss: 0.935914
# Validation accuracy: 0.6392266666666667  Total picks: 225000
# Epoch: 181
# Train Cross-Entropy Loss: 0.934774
# Validation accuracy: 0.6387866666666666  Total picks: 225000
# Epoch: 182
# Train Cross-Entropy Loss: 0.935925
# Validation accuracy: 0.6385733333333333  Total picks: 225000
# Epoch: 183
# Train Cross-Entropy Loss: 0.935442
# Validation accuracy: 0.6384977777777778  Total picks: 225000
# Epoch: 184
# Train Cross-Entropy Loss: 0.935217
# Validation accuracy: 0.6388533333333334  Total picks: 225000
# Epoch: 185
# Train Cross-Entropy Loss: 0.934739
# Validation accuracy: 0.6389422222222222  Total picks: 225000
# Epoch: 186
# Train Cross-Entropy Loss: 0.935577
# Validation accuracy: 0.6385911111111111  Total picks: 225000
# Epoch: 187
# Train Cross-Entropy Loss: 0.934782
# Validation accuracy: 0.63876  Total picks: 225000
# Epoch: 188
# Train Cross-Entropy Loss: 0.935383
# Validation accuracy: 0.6389333333333334  Total picks: 225000
# Epoch: 189
# Train Cross-Entropy Loss: 0.935198
# Validation accuracy: 0.6392533333333333  Total picks: 225000
# Epoch: 190
# Train Cross-Entropy Loss: 0.935916
# Validation accuracy: 0.6387955555555556  Total picks: 225000
# Epoch: 191
# Train Cross-Entropy Loss: 0.934403
# Validation accuracy: 0.6386444444444445  Total picks: 225000
# Epoch: 192
# Train Cross-Entropy Loss: 0.935648
# Validation accuracy: 0.6386977777777778  Total picks: 225000
# Epoch: 193
# Train Cross-Entropy Loss: 0.934504
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 194
# Train Cross-Entropy Loss: 0.934352
# Validation accuracy: 0.6390044444444445  Total picks: 225000
# Epoch: 195
# Train Cross-Entropy Loss: 0.934318
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 196
# Train Cross-Entropy Loss: 0.934918
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 197
# Train Cross-Entropy Loss: 0.934766
# Validation accuracy: 0.6387688888888889  Total picks: 225000
# Epoch: 198
# Train Cross-Entropy Loss: 0.934843
# Validation accuracy: 0.6392133333333333  Total picks: 225000
# Epoch: 199
# Train Cross-Entropy Loss: 0.933792
# Validation accuracy: 0.6385066666666667  Total picks: 225000
# Epoch: 200
# Train Cross-Entropy Loss: 0.935141
# Validation accuracy: 0.6386355555555555  Total picks: 225000
# Epoch: 201
# Train Cross-Entropy Loss: 0.934548
# Validation accuracy: 0.6388444444444444  Total picks: 225000
# Epoch: 202
# Train Cross-Entropy Loss: 0.934732
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 203
# Train Cross-Entropy Loss: 0.934334
# Validation accuracy: 0.6386888888888889  Total picks: 225000
# Epoch: 204
# Train Cross-Entropy Loss: 0.934958
# Validation accuracy: 0.6390177777777778  Total picks: 225000
# Epoch: 205
# Train Cross-Entropy Loss: 0.934123
# Validation accuracy: 0.6385955555555556  Total picks: 225000
# Epoch: 206
# Train Cross-Entropy Loss: 0.935245
# Validation accuracy: 0.6389866666666667  Total picks: 225000
# Epoch: 207
# Train Cross-Entropy Loss: 0.935607
# Validation accuracy: 0.6391333333333333  Total picks: 225000
# Epoch: 208
# Train Cross-Entropy Loss: 0.935023
# Validation accuracy: 0.6390844444444445  Total picks: 225000
# Epoch: 209
# Train Cross-Entropy Loss: 0.934429
# Validation accuracy: 0.6392088888888889  Total picks: 225000
# Epoch: 210
# Train Cross-Entropy Loss: 0.935174
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 211
# Train Cross-Entropy Loss: 0.935639
# Validation accuracy: 0.6390844444444445  Total picks: 225000
# Epoch: 212
# Train Cross-Entropy Loss: 0.934044
# Validation accuracy: 0.6387511111111112  Total picks: 225000
# Epoch: 213
# Train Cross-Entropy Loss: 0.934700
# Validation accuracy: 0.63932  Total picks: 225000
# Epoch: 214
# Train Cross-Entropy Loss: 0.935011
# Validation accuracy: 0.6388177777777778  Total picks: 225000
# Epoch: 215
# Train Cross-Entropy Loss: 0.934287
# Validation accuracy: 0.63912  Total picks: 225000
# Epoch: 216
# Train Cross-Entropy Loss: 0.934159
# Validation accuracy: 0.6386844444444445  Total picks: 225000
# Epoch: 217
# Train Cross-Entropy Loss: 0.934394
# Validation accuracy: 0.6387911111111111  Total picks: 225000
# Epoch: 218
# Train Cross-Entropy Loss: 0.932967
# Validation accuracy: 0.63876  Total picks: 225000
# Epoch: 219
# Train Cross-Entropy Loss: 0.933647
# Validation accuracy: 0.6388266666666667  Total picks: 225000
# Epoch: 220
# Train Cross-Entropy Loss: 0.935235
# Validation accuracy: 0.6388088888888889  Total picks: 225000
# Epoch: 221
# Train Cross-Entropy Loss: 0.934641
# Validation accuracy: 0.6386933333333333  Total picks: 225000
# Epoch: 222
# Train Cross-Entropy Loss: 0.933981
# Validation accuracy: 0.6389111111111111  Total picks: 225000
# Epoch: 223
# Train Cross-Entropy Loss: 0.933790
# Validation accuracy: 0.6389022222222223  Total picks: 225000
# Epoch: 224
# Train Cross-Entropy Loss: 0.933784
# Validation accuracy: 0.6388444444444444  Total picks: 225000
# Epoch: 225
# Train Cross-Entropy Loss: 0.934323
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 226
# Train Cross-Entropy Loss: 0.934756
# Validation accuracy: 0.6389688888888889  Total picks: 225000
# Epoch: 227
# Train Cross-Entropy Loss: 0.935415
# Validation accuracy: 0.6390533333333334  Total picks: 225000
# Epoch: 228
# Train Cross-Entropy Loss: 0.935115
# Validation accuracy: 0.6390844444444445  Total picks: 225000
# Epoch: 229
# Train Cross-Entropy Loss: 0.933132
# Validation accuracy: 0.6390133333333333  Total picks: 225000
# Epoch: 230
# Train Cross-Entropy Loss: 0.934858
# Validation accuracy: 0.6392977777777777  Total picks: 225000
# Epoch: 231
# Train Cross-Entropy Loss: 0.933968
# Validation accuracy: 0.63908  Total picks: 225000
# Epoch: 232
# Train Cross-Entropy Loss: 0.933957
# Validation accuracy: 0.6390622222222222  Total picks: 225000
# Epoch: 233
# Train Cross-Entropy Loss: 0.933621
# Validation accuracy: 0.6390844444444445  Total picks: 225000
# Epoch: 234
# Train Cross-Entropy Loss: 0.934732
# Validation accuracy: 0.6386266666666667  Total picks: 225000
# Epoch: 235
# Train Cross-Entropy Loss: 0.933710
# Validation accuracy: 0.6385288888888889  Total picks: 225000
# Epoch: 236
# Train Cross-Entropy Loss: 0.933268
# Validation accuracy: 0.63888  Total picks: 225000
# Epoch: 237
# Train Cross-Entropy Loss: 0.934179
# Validation accuracy: 0.6387555555555555  Total picks: 225000
# Epoch: 238
# Train Cross-Entropy Loss: 0.933000
# Validation accuracy: 0.6388044444444444  Total picks: 225000
# Epoch: 239
# Train Cross-Entropy Loss: 0.933879
# Validation accuracy: 0.6388577777777777  Total picks: 225000
# Epoch: 240
# Train Cross-Entropy Loss: 0.932884
# Validation accuracy: 0.6386355555555555  Total picks: 225000
# Epoch: 241
# Train Cross-Entropy Loss: 0.933250
# Validation accuracy: 0.6388888888888888  Total picks: 225000
# Epoch: 242
# Train Cross-Entropy Loss: 0.935560
# Validation accuracy: 0.6390222222222223  Total picks: 225000
# Epoch: 243
# Train Cross-Entropy Loss: 0.934322
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 244
# Train Cross-Entropy Loss: 0.934089
# Validation accuracy: 0.6388355555555556  Total picks: 225000
# Epoch: 245
# Train Cross-Entropy Loss: 0.932738
# Validation accuracy: 0.63904  Total picks: 225000
# Epoch: 246
# Train Cross-Entropy Loss: 0.933520
# Validation accuracy: 0.6390266666666666  Total picks: 225000
# Epoch: 247
# Train Cross-Entropy Loss: 0.933764
# Validation accuracy: 0.6386755555555556  Total picks: 225000
# Epoch: 248
# Train Cross-Entropy Loss: 0.934383
# Validation accuracy: 0.63888  Total picks: 225000
# Epoch: 249
# Train Cross-Entropy Loss: 0.934135
# Validation accuracy: 0.6389111111111111  Total picks: 225000
# Epoch: 250
# Train Cross-Entropy Loss: 0.934253
# Validation accuracy: 0.6387822222222223  Total picks: 225000
# Epoch: 251
# Train Cross-Entropy Loss: 0.934042
# Validation accuracy: 0.6392488888888889  Total picks: 225000
# Epoch: 252
# Train Cross-Entropy Loss: 0.934171
# Validation accuracy: 0.6387155555555556  Total picks: 225000
# Epoch: 253
# Train Cross-Entropy Loss: 0.933067
# Validation accuracy: 0.6385688888888889  Total picks: 225000
# Epoch: 254
# Train Cross-Entropy Loss: 0.934656
# Validation accuracy: 0.6390177777777778  Total picks: 225000
# Epoch: 255
# Train Cross-Entropy Loss: 0.933609
# Validation accuracy: 0.6387333333333334  Total picks: 225000
# Epoch: 256
# Train Cross-Entropy Loss: 0.933336
# Validation accuracy: 0.6387244444444444  Total picks: 225000
# Epoch: 257
# Train Cross-Entropy Loss: 0.933360
# Validation accuracy: 0.6391066666666667  Total picks: 225000
# Epoch: 258
# Train Cross-Entropy Loss: 0.933249
# Validation accuracy: 0.6389288888888889  Total picks: 225000
# Epoch: 259
# Train Cross-Entropy Loss: 0.933439
# Validation accuracy: 0.6388444444444444  Total picks: 225000
# Epoch: 260
# Train Cross-Entropy Loss: 0.933050
# Validation accuracy: 0.6386666666666667  Total picks: 225000
# Epoch: 261
# Train Cross-Entropy Loss: 0.933449
# Validation accuracy: 0.6388044444444444  Total picks: 225000
# Epoch: 262
# Train Cross-Entropy Loss: 0.933687
# Validation accuracy: 0.6388  Total picks: 225000
# Epoch: 263
# Train Cross-Entropy Loss: 0.933267
# Validation accuracy: 0.6387866666666666  Total picks: 225000
# Epoch: 264
# Train Cross-Entropy Loss: 0.933944
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 265
# Train Cross-Entropy Loss: 0.933348
# Validation accuracy: 0.6389777777777778  Total picks: 225000
# Epoch: 266
# Train Cross-Entropy Loss: 0.933776
# Validation accuracy: 0.6388222222222222  Total picks: 225000
# Epoch: 267
# Train Cross-Entropy Loss: 0.932834
# Validation accuracy: 0.6390755555555555  Total picks: 225000
# Epoch: 268
# Train Cross-Entropy Loss: 0.932922
# Validation accuracy: 0.6388044444444444  Total picks: 225000
# Epoch: 269
# Train Cross-Entropy Loss: 0.933518
# Validation accuracy: 0.6391066666666667  Total picks: 225000
# Epoch: 270
# Train Cross-Entropy Loss: 0.932783
# Validation accuracy: 0.63884  Total picks: 225000
# Epoch: 271
# Train Cross-Entropy Loss: 0.933716
# Validation accuracy: 0.6387466666666667  Total picks: 225000
# Epoch: 272
# Train Cross-Entropy Loss: 0.931658
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 273
# Train Cross-Entropy Loss: 0.933428
# Validation accuracy: 0.6392311111111111  Total picks: 225000
# Epoch: 274
# Train Cross-Entropy Loss: 0.933311
# Validation accuracy: 0.6391511111111111  Total picks: 225000
# Epoch: 275
# Train Cross-Entropy Loss: 0.933575
# Validation accuracy: 0.6389244444444444  Total picks: 225000
# Epoch: 276
# Train Cross-Entropy Loss: 0.933728
# Validation accuracy: 0.6388488888888889  Total picks: 225000
# Epoch: 277
# Train Cross-Entropy Loss: 0.933173
# Validation accuracy: 0.6385555555555555  Total picks: 225000
# Epoch: 278
# Train Cross-Entropy Loss: 0.932777
# Validation accuracy: 0.6387066666666666  Total picks: 225000
# Epoch: 279
# Train Cross-Entropy Loss: 0.934521
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 280
# Train Cross-Entropy Loss: 0.933129
# Validation accuracy: 0.6388355555555556  Total picks: 225000
# Epoch: 281
# Train Cross-Entropy Loss: 0.933373
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 282
# Train Cross-Entropy Loss: 0.933820
# Validation accuracy: 0.6391777777777777  Total picks: 225000
# Epoch: 283
# Train Cross-Entropy Loss: 0.933584
# Validation accuracy: 0.6392577777777778  Total picks: 225000
# Epoch: 284
# Train Cross-Entropy Loss: 0.932886
# Validation accuracy: 0.6388622222222222  Total picks: 225000
# Epoch: 285
# Train Cross-Entropy Loss: 0.933635
# Validation accuracy: 0.63888  Total picks: 225000
# Epoch: 286
# Train Cross-Entropy Loss: 0.933339
# Validation accuracy: 0.6389422222222222  Total picks: 225000
# Epoch: 287
# Train Cross-Entropy Loss: 0.933173
# Validation accuracy: 0.6386133333333334  Total picks: 225000
# Epoch: 288
# Train Cross-Entropy Loss: 0.933001
# Validation accuracy: 0.6386977777777778  Total picks: 225000
# Epoch: 289
# Train Cross-Entropy Loss: 0.933680
# Validation accuracy: 0.63924  Total picks: 225000
# Epoch: 290
# Train Cross-Entropy Loss: 0.933403
# Validation accuracy: 0.63904  Total picks: 225000
# Epoch: 291
# Train Cross-Entropy Loss: 0.932452
# Validation accuracy: 0.6390488888888889  Total picks: 225000
# Epoch: 292
# Train Cross-Entropy Loss: 0.934322
# Validation accuracy: 0.6386711111111111  Total picks: 225000
# Epoch: 293
# Train Cross-Entropy Loss: 0.932779
# Validation accuracy: 0.6387244444444444  Total picks: 225000
# Epoch: 294
# Train Cross-Entropy Loss: 0.933195
# Validation accuracy: 0.6390133333333333  Total picks: 225000
# Epoch: 295
# Train Cross-Entropy Loss: 0.933291
# Validation accuracy: 0.6390888888888889  Total picks: 225000
# Epoch: 296
# Train Cross-Entropy Loss: 0.932982
# Validation accuracy: 0.63896  Total picks: 225000
# Epoch: 297
# Train Cross-Entropy Loss: 0.933451
# Validation accuracy: 0.6391244444444445  Total picks: 225000
# Epoch: 298
# Train Cross-Entropy Loss: 0.934547
# Validation accuracy: 0.6390044444444445  Total picks: 225000
# Epoch: 299
# Train Cross-Entropy Loss: 0.934459
# Validation accuracy: 0.6387022222222222  Total picks: 225000
# Epoch: 300
# Train Cross-Entropy Loss: 0.933047
# Validation accuracy: 0.6392133333333333  Total picks: 225000
# Epoch: 301
# Train Cross-Entropy Loss: 0.934076
# Validation accuracy: 0.6385244444444445  Total picks: 225000
# Epoch: 302
# Train Cross-Entropy Loss: 0.932479
# Validation accuracy: 0.6389288888888889  Total picks: 225000
# Epoch: 303
# Train Cross-Entropy Loss: 0.933153
# Validation accuracy: 0.6388177777777778  Total picks: 225000
# Epoch: 304
# Train Cross-Entropy Loss: 0.932348
# Validation accuracy: 0.6390044444444445  Total picks: 225000
# Epoch: 305
# Train Cross-Entropy Loss: 0.934278
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 306
# Train Cross-Entropy Loss: 0.933463
# Validation accuracy: 0.6390444444444444  Total picks: 225000
# Epoch: 307
# Train Cross-Entropy Loss: 0.933451
# Validation accuracy: 0.6389022222222223  Total picks: 225000
# Epoch: 308
# Train Cross-Entropy Loss: 0.933425
# Validation accuracy: 0.6388933333333333  Total picks: 225000
# Epoch: 309
# Train Cross-Entropy Loss: 0.932856
# Validation accuracy: 0.6390666666666667  Total picks: 225000
# Epoch: 310
# Train Cross-Entropy Loss: 0.932563
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 311
# Train Cross-Entropy Loss: 0.933275
# Validation accuracy: 0.6388266666666667  Total picks: 225000
# Epoch: 312
# Train Cross-Entropy Loss: 0.932684
# Validation accuracy: 0.6387777777777778  Total picks: 225000
# Epoch: 313
# Train Cross-Entropy Loss: 0.934146
# Validation accuracy: 0.6388311111111111  Total picks: 225000
# Epoch: 314
# Train Cross-Entropy Loss: 0.933637
# Validation accuracy: 0.6387644444444445  Total picks: 225000
# Epoch: 315
# Train Cross-Entropy Loss: 0.933436
# Validation accuracy: 0.6386844444444445  Total picks: 225000
# Epoch: 316
# Train Cross-Entropy Loss: 0.932819
# Validation accuracy: 0.63852  Total picks: 225000
# Epoch: 317
# Train Cross-Entropy Loss: 0.932281
# Validation accuracy: 0.6394044444444444  Total picks: 225000
# Epoch: 318
# Train Cross-Entropy Loss: 0.933200
# Validation accuracy: 0.6388088888888889  Total picks: 225000
# Epoch: 319
# Train Cross-Entropy Loss: 0.932210
# Validation accuracy: 0.6389288888888889  Total picks: 225000
# Epoch: 320
# Train Cross-Entropy Loss: 0.933728
# Validation accuracy: 0.6392622222222222  Total picks: 225000
# Epoch: 321
# Train Cross-Entropy Loss: 0.932492
# Validation accuracy: 0.6389822222222222  Total picks: 225000
# Epoch: 322
# Train Cross-Entropy Loss: 0.933487
# Validation accuracy: 0.6390444444444444  Total picks: 225000
# Epoch: 323
# Train Cross-Entropy Loss: 0.933743
# Validation accuracy: 0.6387022222222222  Total picks: 225000
# Epoch: 324
# Train Cross-Entropy Loss: 0.933022
# Validation accuracy: 0.6389333333333334  Total picks: 225000
# Epoch: 325
# Train Cross-Entropy Loss: 0.933671
# Validation accuracy: 0.6386222222222222  Total picks: 225000
# Epoch: 326
# Train Cross-Entropy Loss: 0.932545
# Validation accuracy: 0.6386888888888889  Total picks: 225000
# Epoch: 327
# Train Cross-Entropy Loss: 0.932918
# Validation accuracy: 0.6391466666666666  Total picks: 225000
# Epoch: 328
# Train Cross-Entropy Loss: 0.933926
# Validation accuracy: 0.6387644444444445  Total picks: 225000
# Epoch: 329
# Train Cross-Entropy Loss: 0.933219
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 330
# Train Cross-Entropy Loss: 0.933837
# Validation accuracy: 0.6389244444444444  Total picks: 225000
# Epoch: 331
# Train Cross-Entropy Loss: 0.933568
# Validation accuracy: 0.63884  Total picks: 225000
# Epoch: 332
# Train Cross-Entropy Loss: 0.933599
# Validation accuracy: 0.6388622222222222  Total picks: 225000
# Epoch: 333
# Train Cross-Entropy Loss: 0.933777
# Validation accuracy: 0.6386444444444445  Total picks: 225000
# Epoch: 334
# Train Cross-Entropy Loss: 0.933376
# Validation accuracy: 0.6387644444444445  Total picks: 225000
# Epoch: 335
# Train Cross-Entropy Loss: 0.933448
# Validation accuracy: 0.6388933333333333  Total picks: 225000
# Epoch: 336
# Train Cross-Entropy Loss: 0.933364
# Validation accuracy: 0.6388977777777778  Total picks: 225000
# Epoch: 337
# Train Cross-Entropy Loss: 0.933773
# Validation accuracy: 0.6389244444444444  Total picks: 225000
# Epoch: 338
# Train Cross-Entropy Loss: 0.933766
# Validation accuracy: 0.6388666666666667  Total picks: 225000
# Epoch: 339
# Train Cross-Entropy Loss: 0.933031
# Validation accuracy: 0.6386622222222222  Total picks: 225000
# Epoch: 340
# Train Cross-Entropy Loss: 0.932280
# Validation accuracy: 0.6384044444444444  Total picks: 225000
# Epoch: 341
# Train Cross-Entropy Loss: 0.933135
# Validation accuracy: 0.6390088888888888  Total picks: 225000
# Epoch: 342
# Train Cross-Entropy Loss: 0.933911
# Validation accuracy: 0.6385866666666666  Total picks: 225000
# Epoch: 343
# Train Cross-Entropy Loss: 0.933517
# Validation accuracy: 0.6386533333333333  Total picks: 225000
# Epoch: 344
# Train Cross-Entropy Loss: 0.932932
# Validation accuracy: 0.6387733333333333  Total picks: 225000
# Epoch: 345
# Train Cross-Entropy Loss: 0.933247
# Validation accuracy: 0.6389022222222223  Total picks: 225000
# Epoch: 346
# Train Cross-Entropy Loss: 0.933210
# Validation accuracy: 0.6389466666666667  Total picks: 225000
# Epoch: 347
# Train Cross-Entropy Loss: 0.932759
# Validation accuracy: 0.6387244444444444  Total picks: 225000
# Epoch: 348
# Train Cross-Entropy Loss: 0.933125
# Validation accuracy: 0.63928  Total picks: 225000
# Epoch: 349
# Train Cross-Entropy Loss: 0.933272
# Validation accuracy: 0.6389066666666666  Total picks: 225000
# Epoch: 350
# Train Cross-Entropy Loss: 0.933257
# Validation accuracy: 0.6384088888888889  Total picks: 225000
# Epoch: 351
# Train Cross-Entropy Loss: 0.932616
# Validation accuracy: 0.6390488888888889  Total picks: 225000
# Epoch: 352
# Train Cross-Entropy Loss: 0.933154
# Validation accuracy: 0.6388755555555555  Total picks: 225000
# Epoch: 353
# Train Cross-Entropy Loss: 0.933141
# Validation accuracy: 0.6389733333333333  Total picks: 225000
# Epoch: 354
# Train Cross-Entropy Loss: 0.932535
# Validation accuracy: 0.6390177777777778  Total picks: 225000
# Epoch: 355
# Train Cross-Entropy Loss: 0.933413
# Validation accuracy: 0.63876  Total picks: 225000
# Epoch: 356
# Train Cross-Entropy Loss: 0.933513
# Validation accuracy: 0.6392088888888889  Total picks: 225000
# Epoch: 357
# Train Cross-Entropy Loss: 0.932552
# Validation accuracy: 0.6386933333333333  Total picks: 225000
# Epoch: 358
# Train Cross-Entropy Loss: 0.932518
# Validation accuracy: 0.6390488888888889  Total picks: 225000
# Epoch: 359
# Train Cross-Entropy Loss: 0.932001
# Validation accuracy: 0.6389911111111111  Total picks: 225000
# Epoch: 360
# Train Cross-Entropy Loss: 0.933037
# Validation accuracy: 0.6387822222222223  Total picks: 225000
# Epoch: 361
# Train Cross-Entropy Loss: 0.932474
# Validation accuracy: 0.6390888888888889  Total picks: 225000
# Epoch: 362
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-e17011f243c4> in <module>()
#      19
#      20     # Train1.
# ---> 21     train_net(net, trainloader, 1, optimizer)
#      22     scheduler.step()
#      23
#
# <ipython-input-225-6b860402cc92> in train_net(net, dataloader, num_epoch, optimizer)
#       7         #Loop over x,y for each dataset.
#       8         running_loss = 0
# ----> 9         for i, data in enumerate(dataloader):
#      10
#      11             my_count+=1
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-4-b323f2cad6a1> in __getitem__(self, index)
#      38
#      39         #Generate.
# ---> 40         x = self.create_new_x(pick_num, draft_num)
#      41         y = self.create_new_y(pick_num, draft_num)
#      42         return x, y
#
# <ipython-input-4-b323f2cad6a1> in create_new_x(self, pick_num, draft_num)
#      61         cards_in_pack =  self.pack_size - pick_num%self.pack_size #Cards in current pack.
#      62         for n in self.drafts_tensor[draft_num, pick_num, :cards_in_pack]:
# ---> 63             x[n + self.cards_in_set] = 1
#      64
#      65         #Convert to Torch tensor.
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.SGD(net.parameters(), lr=0.00001, momentum=0.0)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.8)

ep = 0

for run in range(999999):
    
    ep += 1
    print("Epoch:", ep)
    
    # Train1.
    train_net(net, trainloader, 1, optimizer)
    scheduler.step()
    
    # Validation. 
    val_net(net, valloader)
# Out:
# Epoch: 1
# Train Cross-Entropy Loss: 0.933023
# Validation accuracy: 0.6387644444444445  Total picks: 225000
# Epoch: 2
# Train Cross-Entropy Loss: 0.932756
# Validation accuracy: 0.6389955555555555  Total picks: 225000
# Epoch: 3
# Train Cross-Entropy Loss: 0.933296
# Validation accuracy: 0.63884  Total picks: 225000
# Epoch: 4
# Train Cross-Entropy Loss: 0.932249
# Validation accuracy: 0.6388444444444444  Total picks: 225000
# Epoch: 5
# Train Cross-Entropy Loss: 0.933449
# Validation accuracy: 0.6392  Total picks: 225000
# Epoch: 6
# Train Cross-Entropy Loss: 0.933664
# Validation accuracy: 0.6388933333333333  Total picks: 225000
# Epoch: 7
# Train Cross-Entropy Loss: 0.933211
# Validation accuracy: 0.6389555555555556  Total picks: 225000
# Epoch: 8
# Train Cross-Entropy Loss: 0.932748
# Validation accuracy: 0.6391955555555555  Total picks: 225000
# Epoch: 9
# Train Cross-Entropy Loss: 0.932864
# Validation accuracy: 0.6386533333333333  Total picks: 225000
# Epoch: 10
# Train Cross-Entropy Loss: 0.932511
# Validation accuracy: 0.6387244444444444  Total picks: 225000
# Epoch: 11
# Train Cross-Entropy Loss: 0.932839
# Validation accuracy: 0.6391733333333334  Total picks: 225000
# Epoch: 12
# Train Cross-Entropy Loss: 0.931902
# Validation accuracy: 0.6389333333333334  Total picks: 225000
# Epoch: 13
# Train Cross-Entropy Loss: 0.932418
# Validation accuracy: 0.6387066666666666  Total picks: 225000
# Epoch: 14
# Train Cross-Entropy Loss: 0.932958
# Validation accuracy: 0.6391022222222222  Total picks: 225000
# Epoch: 15
# Train Cross-Entropy Loss: 0.932534
# Validation accuracy: 0.6388266666666667  Total picks: 225000
# Epoch: 16
# Train Cross-Entropy Loss: 0.933444
# Validation accuracy: 0.6390488888888889  Total picks: 225000
# Epoch: 17
# Train Cross-Entropy Loss: 0.932735
# Validation accuracy: 0.6389288888888889  Total picks: 225000
# Epoch: 18
# Train Cross-Entropy Loss: 0.932263
# Validation accuracy: 0.6390844444444445  Total picks: 225000
# Epoch: 19
# Train Cross-Entropy Loss: 0.933159
# Validation accuracy: 0.6383955555555556  Total picks: 225000
# Epoch: 20
# Train Cross-Entropy Loss: 0.933499
# Validation accuracy: 0.6389333333333334  Total picks: 225000
# Epoch: 21
# Train Cross-Entropy Loss: 0.933115
# Validation accuracy: 0.6389555555555556  Total picks: 225000
# Epoch: 22
# Train Cross-Entropy Loss: 0.932618
# Validation accuracy: 0.6388888888888888  Total picks: 225000
# Epoch: 23
# Train Cross-Entropy Loss: 0.932824
# Validation accuracy: 0.639  Total picks: 225000
# Epoch: 24
# Train Cross-Entropy Loss: 0.933239
# Validation accuracy: 0.6392577777777778  Total picks: 225000
# Epoch: 25
# Train Cross-Entropy Loss: 0.932424
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 26
# Train Cross-Entropy Loss: 0.932542
# Validation accuracy: 0.6386977777777778  Total picks: 225000
# Epoch: 27
# Train Cross-Entropy Loss: 0.932608
# Validation accuracy: 0.6387377777777777  Total picks: 225000
# Epoch: 28
# Train Cross-Entropy Loss: 0.932838
# Validation accuracy: 0.6389955555555555  Total picks: 225000
# Epoch: 29
# Train Cross-Entropy Loss: 0.933041
# Validation accuracy: 0.6388044444444444  Total picks: 225000
# Epoch: 30
# Train Cross-Entropy Loss: 0.933164
# Validation accuracy: 0.6389466666666667  Total picks: 225000
# Epoch: 31
# Train Cross-Entropy Loss: 0.933524
# Validation accuracy: 0.6387333333333334  Total picks: 225000
# Epoch: 32
# Train Cross-Entropy Loss: 0.932631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-229-282d763e4f47> in <module>()
#      15
#      16     # Validation.
# ---> 17     val_net(net, valloader)
#
# <ipython-input-227-d6e587457496> in val_net(net, dataloader)
#       6
#       7     with torch.no_grad():
# ----> 8         for i, data in enumerate(dataloader):
#       9
#      10             #Get the inputs. Keeps batch size.
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-4-b323f2cad6a1> in __getitem__(self, index)
#      38
#      39         #Generate.
# ---> 40         x = self.create_new_x(pick_num, draft_num)
#      41         y = self.create_new_y(pick_num, draft_num)
#      42         return x, y
#
# <ipython-input-4-b323f2cad6a1> in create_new_x(self, pick_num, draft_num)
#      56         #Fill in collection vector excluding current pick (first half).
#      57         for n in self.drafts_tensor[draft_num, :pick_num, 0]:
# ---> 58             x[n] += 1
#      59
#      60         #Fill in pack vector.
#
# KeyboardInterrupt:
