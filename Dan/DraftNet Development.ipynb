# %% [markdown]
# # DraftNet Development
# daniel.brooks@alumni.caltech.edu <br>
# July 1, 2019 <br>

# %%
#Preprocessing imports.
import numpy as np
from sklearn import preprocessing
from tqdm import tqdm

import draftsimtools as ds

# %%
#Torch imports.
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.dataset import Dataset

# %% [markdown]
# # Load the Dataset

# %%
# Toggle GPU/CPU mode.
# device = torch.device("cpu")
device = torch.device("cuda:0")

# %%
# This cell now included in draftsimtools (without GPU support).
def create_le(cardnames):
    """Create label encoder for cardnames."""
    le = preprocessing.LabelEncoder()
    le.fit(cardnames)
    return le

def draft_to_matrix(cur_draft, le, pack_size=15):
    """Transform draft from cardname list to one hot encoding."""
    pick_list = [np.append(le.transform(cur_draft[i]), (pack_size-len(x))*[0]) \
                 for i, x in enumerate(cur_draft)]
    pick_matrix = np.int16(pick_list, device=device)
    return pick_matrix

def drafts_to_tensor(drafts, le, pack_size=15):
    """Create tensor of shape (num_drafts, 45, 15)."""
    pick_tensor_list = [draft_to_matrix(d, le) for d in drafts]
    pick_tensor = np.int16(pick_tensor_list, device=device)
    return pick_tensor

#Drafts dataset class.
class DraftDataset(Dataset):
    """Defines a draft dataset in PyTorch."""
    
    def __init__(self, drafts_tensor, le):
        """Initialization.
        """
        self.drafts_tensor = drafts_tensor
        self.le = le
        self.cards_in_set = len(self.le.classes_)
        self.pack_size = int(self.drafts_tensor.shape[1]/3)
        self.draft_size = self.pack_size*3
        
    def __getitem__(self, index):
        """Return a training example.
        """
        #Grab information on current draft.
        pick_num = index % self.draft_size #0-self.pack_size*3-1
        draft_num = int((index - pick_num)/self.draft_size)
        
        #Generate.
        x = self.create_new_x(pick_num, draft_num)
        y = self.create_new_y(pick_num, draft_num)
        return x, y
    
    def create_new_x(self, pick_num, draft_num):
        """Generate x, input, as a row vector.
        0:n     : collection vector
                  x[i]=n -> collection has n copies of card i
        n:2n    : pack vector
                  0 -> card not in pack
                  1 -> card in pack
        Efficiency optimization possible. Iterative adds to numpy array.
        """
        #Initialize collection / cards in pack vector.
        x = np.zeros([self.cards_in_set * 2], dtype = "int16")
        
        #Fill in collection vector excluding current pick (first half).
        for n in self.drafts_tensor[draft_num, :pick_num, 0]:
            x[n] += 1
            
        #Fill in pack vector.
        cards_in_pack =  self.pack_size - pick_num%self.pack_size #Cards in current pack.
        for n in self.drafts_tensor[draft_num, pick_num, :cards_in_pack]:
            x[n + self.cards_in_set] = 1
            
        #Convert to Torch tensor.
        x = torch.Tensor(x)
        return x
    
    def create_new_y(self, pick_num, draft_num, not_in_pack=0.5):
        """Generate y, a target pick row vector.
        Picked card is assigned a value of 1.
        Other cards are assigned a value of 0.
        """
        #Initialize target vector.
        #y = np.array([0] * self.cards_in_set)
        y = np.zeros([self.cards_in_set], dtype = "int16")
            
        #Add picked card.
        y[self.drafts_tensor[draft_num, pick_num, 0]] = 1
        #y = torch.Tensor(y, dtype=torch.int64) # Needed as target.
        y = torch.tensor(y, dtype=torch.int64, device=device) # Needed as target.
        return y
    
    def __len__(self):
        return len(self.drafts_tensor) * self.draft_size

def load_dataset(rating_path1, rating_path2, drafts_path):
    """Create drafts tensor from drafts and set files."""
    # Load the set. inputs
    cur_set = ds.create_set(rating_path1, rating_path2)
    raw_drafts = ds.load_drafts(drafts_path)
    
    # Fix commas. 
    cur_set, raw_drafts = ds.fix_commas(cur_set, raw_drafts)
    
    # Process drafts. 
    drafts = ds.process_drafts(raw_drafts)
    
    # Drop empty elements at end, if present. 
    while len(drafts[-1]) == 0:
        drafts = drafts[:-1]
    
    # Create a label encoder.
    le = create_le(cur_set["Name"].values)
    
    # Create drafts tensor. 
    drafts_tensor = drafts_to_tensor(drafts, le)
    
    # Create a dataset.
    cur_dataset = DraftDataset(drafts_tensor, le)
    
    # Get the tensor
    return cur_dataset, drafts_tensor, cur_set, le

# %%
# Define rating file paths. 
rating_path1 = "data/m19_rating.tsv"
rating_path2 = "data/m19_land_rating.tsv"

# Load data. 
train_data, train_tensor, m19_set, le = ds.load_dataset(rating_path1, rating_path2, "data/subset20000/train.csv")
val_data, val_tensor, m19_set, le = ds.load_dataset(rating_path1, rating_path2, "data/subset20000/val.csv")
#test_data, test_tensor, m19_set, le = load_dataset(rating_path1, rating_path2, "data/subset20000/test.csv")
# Out:
# Processing draft: 0.
# Processing draft: 10000.
# Processing draft: 0.

# %%
m19_set.head()
# Out:
#                    Name Casting Cost 1 Casting Cost 2 Card Type Rarity  \
# 0    Abnormal_Endurance             1B           none   Instant      C
# 1        Act_of_Treason             2R           none     Spell      C
# 2  Aegis_of_the_Heavens             1W           none   Instant      U
# 3       Aerial_Engineer            2UW           none  Creature      U
# 4         Aether_Tunnel             1U           none     Spell      U
#
#    Rating     Color Vector
# 0     2.2  [0, 0, 1, 0, 0]
# 1     2.0  [0, 0, 0, 1, 0]
# 2     1.9  [1, 0, 0, 0, 0]
# 3     3.0  [1, 1, 0, 0, 0]
# 4     2.0  [0, 1, 0, 0, 0]

# %%
def create_set_vector(casting_cost, card_type, rarity, color_vector):
    """
    Returns a one hot encoded card property vector. 
    
    There are 21 binary features:
    
    0. cmc=0
    1. cmc=1
    2. cmc=2
    3. cmc=3
    4. cmc=4
    5. cmc=5
    6. cmc=6
    7. cmc>=7
    8. creature?
    9. common?
    10. uncommon?
    11. rare?
    12. mythic?
    13. colorless?
    14. monocolored?
    15. multicolored?
    16. color1?
    17. color2?
    18. color3?
    19. color4?
    20. color5?
    
    :param casting_cost: integer casting cost of card
    :param card_type: "Creature" or other
    :param rarity": "C", "U", "R", or "M"
    "param color_vector": vector corresponding to colors of card, example: [1,0,0,0,1]
    
    """
    # Initialize set vector.
    v = [0] * 21
    
    # Encode cmc. 
    if casting_cost == 0:
        v[0] = 1
    elif casting_cost == 1:
        v[1] = 1
    elif casting_cost == 2:
        v[2] = 1
    elif casting_cost == 3:
        v[3] = 1
    elif casting_cost == 4:
        v[4] = 1
    elif casting_cost == 5:
        v[5] = 1
    elif casting_cost == 6:
        v[6] = 1
    elif casting_cost >= 7:
        v[7] = 1
    else:
        print("WARNING: Undefined casting cost.")
    
    # Encode type.
    if card_type == "Creature":
        v[8] = 1
        
    # Encode rarity.
    if rarity == "C":
        v[9] = 1
    elif rarity == "U":
        v[10] = 1
    elif rarity == "R":
        v[11] = 1
    elif rarity == "M":
        v[12] = 1
    
    # Process number of colors.
    num_colors = len([c for c in color_vector if c > 0])
    if num_colors == 0:
        v[13] = 1
    elif num_colors == 1:
        v[14] = 1
    elif num_colors >= 2:
        v[15] = 1
    
    # Process card color. 
    if color_vector[0] > 0:
        v[16] = 1
    if color_vector[1] > 0:
        v[17] = 1
    if color_vector[2] > 0:
        v[18] = 1
    if color_vector[3] > 0:
        v[19] = 1
    if color_vector[4] > 0:
        v[20] = 1
    return v

# %%
def cmc_from_string(cmc_string):
    """
    Return an integer converted mana cost from cmc_string. 
    
    Each character adds 1 to cmc. 
    
    :param cmc_string: String or integer representation of cmc. Example: "1UBR".
    :returns: Integer cmc. Example: 4.
    """
    # If int, we are done. 
    if type(cmc_string) is int:
        return cmc_string
    
    # Convert string to integer cmc.
    cmc = 0
    digit_string = ""
    letters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")
    digits = set("1234567890")
        
    for c in cmc_string:        
        if c in letters:
            cmc += 1
        else:
            digit_string += c
    if len(digit_string) > 0:
        cmc += int(digit_string)
    return cmc

# %%
def create_set_tensor(magic_set):
    """
    Returns a set tensor which represents the properties of cards in the set.
    
    There are M features and N cards in the set and the tensor is of size M x N.
    
    The features are documented in the create_set_vector() function. 
    """
    set_list = []
    
    # Requires these names to be present in the set file.
    reduced_set = magic_set[["Name", "Casting Cost 1", "Card Type", "Rarity", "Color Vector"]]
    for index, row in reduced_set.iterrows():
        card_vector = create_set_vector(cmc_from_string(row[1]), row[2], row[3], row[4])
        set_list.append(card_vector)
        
    # set_list is currently N x M list of lists. 
    set_flipped = torch.Tensor(set_list)
    set_tensor = torch.transpose(set_flipped, 0, 1)
    return set_tensor

# %%
# Set tensor.
st = create_set_tensor(m19_set).cuda()
print(st.shape)
# Out:
# torch.Size([21, 285])

# %% [markdown]
# # Define the NN

# %%
#Implement NN.
class DraftNet(nn.Module):
    
    def __init__(self, set_tensor):
        """Placeholder NN. Currently does nothing.
        
        param ss: number of cards in set
        param set_tensor: Mxss set tensor describing the set
        """
        super(DraftNet, self).__init__()
        
        # Load set tensor.
        self.set_tensor = set_tensor
        self.set_tensor_tranpose = torch.transpose(set_tensor, 0, 1)
        self.M, self.ss = self.set_tensor.shape
        self.half_ss = self.ss / 2
        
        # Specify layer sizes. 
        size_in = self.ss + self.M
        #size_in = self.ss
        size1 = self.ss
        size2 = self.ss
        size3 = self.ss
        size4 = self.ss
        size5 = self.ss
        size6 = self.ss
        size7 = self.ss
        size8 = self.ss
        
        self.ns = 0.01
        
        self.bn = nn.BatchNorm1d(self.ss + self.M)
        
        self.linear1 = torch.nn.Linear(size_in, size1)
        self.bn1 = nn.BatchNorm1d(size1)
        self.relu1 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout1 = nn.Dropout(0.5)
        
        self.linear2 = torch.nn.Linear(size1, size2)
        self.bn2 = nn.BatchNorm1d(size2)
        self.relu2 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout2 = nn.Dropout(0.5)
        
        self.linear3 = torch.nn.Linear(size2, size3)
        self.bn3 = nn.BatchNorm1d(size3)
        self.relu3 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout3 = nn.Dropout(0.5)
        
        self.linear4 = torch.nn.Linear(size3, size4)
        self.relu4 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout4 = nn.Dropout(0.5)
        
        self.linear5 = torch.nn.Linear(size3, size5)
        self.relu5 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout5 = nn.Dropout(0.5)
        
        self.linear6 = torch.nn.Linear(size3, size6)
        self.relu6 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout6 = nn.Dropout(0.5)
        
        self.linear7 = torch.nn.Linear(size3, size7)
        self.relu7 = torch.nn.LeakyReLU(negative_slope = self.ns)
        self.dropout7 = nn.Dropout(0.5)
        
        self.linear8 = torch.nn.Linear(size3, size8)
        self.relu8 = torch.nn.LeakyReLU(negative_slope = self.ns)
        
        
        #self.sm = torch.nn.Softmax()
                
    def forward(self, x):
        
        collection = x[:, :self.ss]
        
        #collection = self.bn(collection)
        
        pack = x[:, self.ss:]
        
        # Get features from set tensor. 
        features = torch.mm(collection, self.set_tensor_tranpose)
        collection_and_features = torch.cat((collection, features), 1)
        
        collection_and_features = self.bn(collection_and_features)
        
        #y = self.linear1(collection_and_features)
        y = self.linear1(collection_and_features)
        y = self.bn1(y)
        y = self.relu1(y)
        y = self.dropout1(y)
        
        y = self.linear2(y)
        y = self.bn2(y)
        y = self.relu2(y)
        y = self.dropout2(y)
        
        y = self.linear3(y)
        y = self.bn3(y)
        y = self.relu3(y)
        y = self.dropout3(y)

        y = self.linear4(y)
        #y = self.relu4(y)
        #y = self.dropout4(y)
        
        #y = self.linear5(y)
        #y = self.relu5(y)
        #y = self.dropout5(y)
        
        #y = self.linear6(y)
        #y = self.relu6(y)
        #y = self.dropout6(y)
        
        #y = self.linear7(y)
        #y = self.relu7(y)
        #y = self.dropout7(y)
        
        #y = self.linear8(y)
        #y = self.relu8(y)
        
        y = y * pack # Enforce cards in pack only.
        
        return y

#Create NN.
net = DraftNet(st).cuda()
#print(net)

# %% [markdown]
# # Network training

# %%
def train_net(net, dataloader, num_epoch, optimizer):
    """Train the network."""
    net.train()    
    my_count = 0
    for epoch in range(num_epoch):
        
        #Loop over x,y for each dataset.
        running_loss = 0
        for i, data in enumerate(dataloader):
        
            my_count+=1
            if my_count % 10000 == 0:
                print(my_count)
        
            #Get the inputs. Keeps batch size.
            x, y = data
            
            # cuda() is needed for GPU mode. Not sure why.
            x = x.cuda()
            y = y.cuda() # One-hot encoded. 
            
            # Zero parameter gradients between batches.
            optimizer.zero_grad()
        
            #Perform training.
            y_pred = net(x)
            y_integer = torch.argmax(y, 1) # Class indices.
            
            # Use cross entropy loss. 
            loss = torch.nn.CrossEntropyLoss()
            output = loss(y_pred, y_integer)
            output.backward()
            optimizer.step()
                        
            #Print loss data.
            running_loss += output.item()
            step = 1
            if i % len(dataloader) == len(dataloader)-1 and (epoch + 1) % step == 0:
                print('Train Cross-Entropy Loss: %.6f' % (running_loss/len(dataloader)))
                running_loss = 0.0

# %%
# Define dataloaders. 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=100, shuffle=True)
valloader = torch.utils.data.DataLoader(val_data, batch_size=100, shuffle=False)

# %% [markdown]
# # Network validation

# %%
def val_net(net, dataloader):
    """Compute accuracy on validation set."""
    net.eval()
    correct = 0.0
    total = 0.0
    
    with torch.no_grad():
        for i, data in enumerate(dataloader):
        
            #Get the inputs. Keeps batch size.
            x, y = data
            
            # cuda() is needed for GPU mode. Not sure why.
            x = x.cuda()
            y = y.cuda()
            y_integer = torch.argmax(y, 1) # Class indices.
            
            # Compute val loss.
            y_pred = net(x)
            y_pred_integer = torch.argmax(y_pred, 1)
            
            # Compute accuracy. 
            correct += int(sum(y_pred_integer == y_integer))
            total += len(y_integer)
            
    accuracy = correct / total

    print("Validation accuracy:", accuracy, " Total picks:", int(total))

# %%
# Train the network over several epochs - no momentu, from scratch.
run = 0

# Now leave optimizer out here. 
#optimizer = optim.Adam(net.parameters(), lr=0.05, betas=(0.9, 0.999))
#optimizer = optim.ASGD(net.parameters())
#optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.9)

optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.0)
#optimizer = torch.optim.RMSprop(net.parameters(), lr=0.1, momentum=0.0)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.85)

ep = 0

for run in range(999999):
    
    ep += 1
    print("Epoch:", ep)
    
    # Train1.
    train_net(net, trainloader, 1, optimizer)
    scheduler.step()
    
    # Validation. 
    val_net(net, valloader)
# Out:
# Epoch: 1
# Train Cross-Entropy Loss: 1.553937
# Validation accuracy: 0.6085377777777777  Total picks: 225000
# Epoch: 2
# Train Cross-Entropy Loss: 1.133962
# Validation accuracy: 0.6135822222222223  Total picks: 225000
# Epoch: 3
# Train Cross-Entropy Loss: 1.096933
# Validation accuracy: 0.6212266666666667  Total picks: 225000
# Epoch: 4
# Train Cross-Entropy Loss: 1.073166
# Validation accuracy: 0.6237466666666667  Total picks: 225000
# Epoch: 5
# Train Cross-Entropy Loss: 1.058938
# Validation accuracy: 0.6269511111111111  Total picks: 225000
# Epoch: 6
# Train Cross-Entropy Loss: 1.046276
# Validation accuracy: 0.6287733333333333  Total picks: 225000
# Epoch: 7
# Train Cross-Entropy Loss: 1.039295
# Validation accuracy: 0.6297688888888889  Total picks: 225000
# Epoch: 8
# Train Cross-Entropy Loss: 1.032156
# Validation accuracy: 0.6310044444444445  Total picks: 225000
# Epoch: 9
# Train Cross-Entropy Loss: 1.026030
# Validation accuracy: 0.6316311111111111  Total picks: 225000
# Epoch: 10
# Train Cross-Entropy Loss: 1.021769
# Validation accuracy: 0.6321066666666667  Total picks: 225000
# Epoch: 11
# Train Cross-Entropy Loss: 1.017276
# Validation accuracy: 0.6323822222222222  Total picks: 225000
# Epoch: 12
# Train Cross-Entropy Loss: 1.014509
# Validation accuracy: 0.63416  Total picks: 225000
# Epoch: 13
# Train Cross-Entropy Loss: 1.012845
# Validation accuracy: 0.6340577777777778  Total picks: 225000
# Epoch: 14
# Train Cross-Entropy Loss: 1.009616
# Validation accuracy: 0.6348088888888889  Total picks: 225000
# Epoch: 15
# Train Cross-Entropy Loss: 1.007456
# Validation accuracy: 0.635  Total picks: 225000
# Epoch: 16
# Train Cross-Entropy Loss: 1.005283
# Validation accuracy: 0.6347511111111112  Total picks: 225000
# Epoch: 17
# Train Cross-Entropy Loss: 1.004005
# Validation accuracy: 0.6357644444444445  Total picks: 225000
# Epoch: 18
# Train Cross-Entropy Loss: 1.002222
# Validation accuracy: 0.6356488888888889  Total picks: 225000
# Epoch: 19
# Train Cross-Entropy Loss: 1.002358
# Validation accuracy: 0.6357822222222222  Total picks: 225000
# Epoch: 20
# Train Cross-Entropy Loss: 1.001201
# Validation accuracy: 0.6362444444444444  Total picks: 225000
# Epoch: 21
# Train Cross-Entropy Loss: 1.000541
# Validation accuracy: 0.6360977777777778  Total picks: 225000
# Epoch: 22
# Train Cross-Entropy Loss: 0.999709
# Validation accuracy: 0.6364622222222223  Total picks: 225000
# Epoch: 23
# Train Cross-Entropy Loss: 1.000368
# Validation accuracy: 0.6363377777777778  Total picks: 225000
# Epoch: 24
# Train Cross-Entropy Loss: 0.998856
# Validation accuracy: 0.6361733333333334  Total picks: 225000
# Epoch: 25
# Train Cross-Entropy Loss: 0.998599
# Validation accuracy: 0.6366133333333334  Total picks: 225000
# Epoch: 26
# Train Cross-Entropy Loss: 0.996829
# Validation accuracy: 0.6361555555555556  Total picks: 225000
# Epoch: 27
# Train Cross-Entropy Loss: 0.996960
# Validation accuracy: 0.6361911111111112  Total picks: 225000
# Epoch: 28
# Train Cross-Entropy Loss: 0.997105
# Validation accuracy: 0.6365733333333333  Total picks: 225000
# Epoch: 29
# Train Cross-Entropy Loss: 0.996721
# Validation accuracy: 0.6364622222222223  Total picks: 225000
# Epoch: 30
# Train Cross-Entropy Loss: 0.997393
# Validation accuracy: 0.6360355555555556  Total picks: 225000
# Epoch: 31
# Train Cross-Entropy Loss: 0.997244
# Validation accuracy: 0.6361688888888889  Total picks: 225000
# Epoch: 32
# Train Cross-Entropy Loss: 0.996224
# Validation accuracy: 0.6361955555555555  Total picks: 225000
# Epoch: 33
# Train Cross-Entropy Loss: 0.995978
# Validation accuracy: 0.6363511111111111  Total picks: 225000
# Epoch: 34
# Train Cross-Entropy Loss: 0.996535
# Validation accuracy: 0.6365911111111111  Total picks: 225000
# Epoch: 35
# Train Cross-Entropy Loss: 0.996393
# Validation accuracy: 0.6365288888888889  Total picks: 225000
# Epoch: 36
# Train Cross-Entropy Loss: 0.995589
# Validation accuracy: 0.6361911111111112  Total picks: 225000
# Epoch: 37
# Train Cross-Entropy Loss: 0.996591
# Validation accuracy: 0.6363822222222222  Total picks: 225000
# Epoch: 38
# Train Cross-Entropy Loss: 0.995449
# Validation accuracy: 0.6365555555555555  Total picks: 225000
# Epoch: 39
# Train Cross-Entropy Loss: 0.995147
# Validation accuracy: 0.6360533333333334  Total picks: 225000
# Epoch: 40
# Train Cross-Entropy Loss: 0.995182
# Validation accuracy: 0.63644  Total picks: 225000
# Epoch: 41
# Train Cross-Entropy Loss: 0.995917
# Validation accuracy: 0.6362666666666666  Total picks: 225000
# Epoch: 42
# Train Cross-Entropy Loss: 0.996826
# Validation accuracy: 0.636  Total picks: 225000
# Epoch: 43
# Train Cross-Entropy Loss: 0.995098
# Validation accuracy: 0.6368577777777777  Total picks: 225000
# Epoch: 44
# Train Cross-Entropy Loss: 0.995207
# Validation accuracy: 0.6362266666666667  Total picks: 225000
# Epoch: 45
# Train Cross-Entropy Loss: 0.995704
# Validation accuracy: 0.6367555555555555  Total picks: 225000
# Epoch: 46
# Train Cross-Entropy Loss: 0.996151
# Validation accuracy: 0.6366533333333333  Total picks: 225000
# Epoch: 47
# Train Cross-Entropy Loss: 0.995418
# Validation accuracy: 0.6361288888888889  Total picks: 225000
# Epoch: 48
# Train Cross-Entropy Loss: 0.995645
# Validation accuracy: 0.6361466666666666  Total picks: 225000
# Epoch: 49
# Train Cross-Entropy Loss: 0.994780
# Validation accuracy: 0.6364488888888888  Total picks: 225000
# Epoch: 50
# Train Cross-Entropy Loss: 0.996470
# Validation accuracy: 0.6367111111111111  Total picks: 225000
# Epoch: 51
# Train Cross-Entropy Loss: 0.995024
# Validation accuracy: 0.63664  Total picks: 225000
# Epoch: 52
# Train Cross-Entropy Loss: 0.995344
# Validation accuracy: 0.6368755555555555  Total picks: 225000
# Epoch: 53
# Train Cross-Entropy Loss: 0.994738
# Validation accuracy: 0.6365111111111111  Total picks: 225000
# Epoch: 54
# Train Cross-Entropy Loss: 0.995871
# Validation accuracy: 0.63624  Total picks: 225000
# Epoch: 55
# Train Cross-Entropy Loss: 0.995960
# Validation accuracy: 0.6365955555555556  Total picks: 225000
# Epoch: 56
# Train Cross-Entropy Loss: 0.995504
# Validation accuracy: 0.6363244444444445  Total picks: 225000
# Epoch: 57
# Train Cross-Entropy Loss: 0.995636
# Validation accuracy: 0.63628  Total picks: 225000
# Epoch: 58
# Train Cross-Entropy Loss: 0.995922
# Validation accuracy: 0.63612  Total picks: 225000
# Epoch: 59
# Train Cross-Entropy Loss: 0.994813
# Validation accuracy: 0.6365955555555556  Total picks: 225000
# Epoch: 60
# Train Cross-Entropy Loss: 0.995740
# Validation accuracy: 0.6364755555555556  Total picks: 225000
# Epoch: 61
# Train Cross-Entropy Loss: 0.996685
# Validation accuracy: 0.6356622222222222  Total picks: 225000
# Epoch: 62
# Train Cross-Entropy Loss: 0.996605
# Validation accuracy: 0.6364222222222222  Total picks: 225000
# Epoch: 63
# Train Cross-Entropy Loss: 0.995856
# Validation accuracy: 0.6366088888888889  Total picks: 225000
# Epoch: 64
# Train Cross-Entropy Loss: 0.995338
# Validation accuracy: 0.6359644444444444  Total picks: 225000
# Epoch: 65
# Train Cross-Entropy Loss: 0.995425
# Validation accuracy: 0.6364311111111111  Total picks: 225000
# Epoch: 66
# Train Cross-Entropy Loss: 0.995612
# Validation accuracy: 0.6360577777777778  Total picks: 225000
# Epoch: 67
# Train Cross-Entropy Loss: 0.995431
# Validation accuracy: 0.63628  Total picks: 225000
# Epoch: 68
# Train Cross-Entropy Loss: 0.994696
# Epoch: 96
# Train Cross-Entropy Loss: 0.995528
# Validation accuracy: 0.6359911111111111  Total picks: 225000
# Epoch: 97
# Train Cross-Entropy Loss: 0.995325
# Validation accuracy: 0.6363777777777778  Total picks: 225000
# Epoch: 98
# Train Cross-Entropy Loss: 0.995454
# Validation accuracy: 0.6366355555555555  Total picks: 225000
# Epoch: 99
# Train Cross-Entropy Loss: 0.994618
# Validation accuracy: 0.6366622222222222  Total picks: 225000
# Epoch: 100
# Train Cross-Entropy Loss: 0.995484
# Validation accuracy: 0.6364  Total picks: 225000
# Epoch: 101
# Train Cross-Entropy Loss: 0.995719
# Validation accuracy: 0.6362622222222222  Total picks: 225000
# Epoch: 102
# Train Cross-Entropy Loss: 0.994045
# Validation accuracy: 0.6358622222222222  Total picks: 225000
# Epoch: 103
# Train Cross-Entropy Loss: 0.995547
# Validation accuracy: 0.6362444444444444  Total picks: 225000
# Epoch: 104
# Train Cross-Entropy Loss: 0.995452
# Validation accuracy: 0.6362711111111111  Total picks: 225000
# Epoch: 105
# Train Cross-Entropy Loss: 0.995947
# Validation accuracy: 0.6366444444444445  Total picks: 225000
# Epoch: 106
# Train Cross-Entropy Loss: 0.995314
# Validation accuracy: 0.6365333333333333  Total picks: 225000
# Epoch: 107
# Train Cross-Entropy Loss: 0.994993
# Validation accuracy: 0.6362933333333334  Total picks: 225000
# Epoch: 108
# Train Cross-Entropy Loss: 0.994943
# Validation accuracy: 0.6365377777777778  Total picks: 225000
# Epoch: 109
# Train Cross-Entropy Loss: 0.995072
# Validation accuracy: 0.6366311111111111  Total picks: 225000
# Epoch: 110
# Train Cross-Entropy Loss: 0.995352
# Validation accuracy: 0.6364  Total picks: 225000
# Epoch: 111
# Train Cross-Entropy Loss: 0.996818
# Validation accuracy: 0.6364088888888889  Total picks: 225000
# Epoch: 112
# Train Cross-Entropy Loss: 0.995666
# Validation accuracy: 0.6366533333333333  Total picks: 225000
# Epoch: 113
# Train Cross-Entropy Loss: 0.995343
# Validation accuracy: 0.6364844444444444  Total picks: 225000
# Epoch: 114
# Train Cross-Entropy Loss: 0.996492
# Validation accuracy: 0.6363111111111112  Total picks: 225000
# Epoch: 115
# Train Cross-Entropy Loss: 0.995683
# Validation accuracy: 0.6366133333333334  Total picks: 225000
# Epoch: 116
# Train Cross-Entropy Loss: 0.995152
# Validation accuracy: 0.6363822222222222  Total picks: 225000
# Epoch: 117
# Train Cross-Entropy Loss: 0.996040
# Validation accuracy: 0.6364666666666666  Total picks: 225000
# Epoch: 118
# Train Cross-Entropy Loss: 0.995099
# Validation accuracy: 0.6366711111111111  Total picks: 225000
# Epoch: 119
# Train Cross-Entropy Loss: 0.995479
# Validation accuracy: 0.6363511111111111  Total picks: 225000
# Epoch: 120
# Train Cross-Entropy Loss: 0.995773
# Validation accuracy: 0.6365288888888889  Total picks: 225000
# Epoch: 121
# Train Cross-Entropy Loss: 0.995795
# Validation accuracy: 0.6367422222222222  Total picks: 225000
# Epoch: 122
# Train Cross-Entropy Loss: 0.995698
# Validation accuracy: 0.6365822222222223  Total picks: 225000
# Validation accuracy: 0.6360933333333333  Total picks: 225000
# Epoch: 341
# Train Cross-Entropy Loss: 0.995862
# Validation accuracy: 0.6363377777777778  Total picks: 225000
# Epoch: 342
# Train Cross-Entropy Loss: 0.995592
# Validation accuracy: 0.6365911111111111  Total picks: 225000
# Epoch: 343
# Train Cross-Entropy Loss: 0.995259
# Validation accuracy: 0.6363822222222222  Total picks: 225000
# Epoch: 344
# Train Cross-Entropy Loss: 0.994906
# Validation accuracy: 0.6368755555555555  Total picks: 225000
# Epoch: 345
# Train Cross-Entropy Loss: 0.995644
# Validation accuracy: 0.6367733333333333  Total picks: 225000
# Epoch: 346
# Train Cross-Entropy Loss: 0.996591
# Validation accuracy: 0.6361777777777777  Total picks: 225000
# Epoch: 347
# Train Cross-Entropy Loss: 0.995592
# Validation accuracy: 0.6361288888888889  Total picks: 225000
# Epoch: 348
# Train Cross-Entropy Loss: 0.995959
# Validation accuracy: 0.6366133333333334  Total picks: 225000
# Epoch: 349
# Train Cross-Entropy Loss: 0.996290
# Validation accuracy: 0.6362177777777778  Total picks: 225000
# Epoch: 350
# Train Cross-Entropy Loss: 0.995716
# Validation accuracy: 0.6362133333333333  Total picks: 225000
# Epoch: 351
# Train Cross-Entropy Loss: 0.995343
# Validation accuracy: 0.6362044444444445  Total picks: 225000
# Epoch: 352
# Train Cross-Entropy Loss: 0.994770
# Validation accuracy: 0.63632  Total picks: 225000
# Epoch: 353
# Train Cross-Entropy Loss: 0.995037
# Validation accuracy: 0.6362133333333333  Total picks: 225000
# Epoch: 354
# Train Cross-Entropy Loss: 0.995485
# Validation accuracy: 0.6363288888888889  Total picks: 225000
# Epoch: 355
# Train Cross-Entropy Loss: 0.995392
# Validation accuracy: 0.6366933333333333  Total picks: 225000
# Epoch: 356
# Train Cross-Entropy Loss: 0.995277
# Validation accuracy: 0.6362577777777778  Total picks: 225000
# Epoch: 357
# Train Cross-Entropy Loss: 0.996173
# Validation accuracy: 0.6363511111111111  Total picks: 225000
# Epoch: 358
# Train Cross-Entropy Loss: 0.995891
# Validation accuracy: 0.6363288888888889  Total picks: 225000
# Epoch: 359
# Train Cross-Entropy Loss: 0.996020
# Validation accuracy: 0.6365955555555556  Total picks: 225000
# Epoch: 360
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-b8db3157d596> in <module>()
#      20
#      21     # Train1.
# ---> 22     train_net(net, trainloader, 1, optimizer)
#      23     scheduler.step()
#      24
#
# <ipython-input-52-6b860402cc92> in train_net(net, dataloader, num_epoch, optimizer)
#       7         #Loop over x,y for each dataset.
#       8         running_loss = 0
# ----> 9         for i, data in enumerate(dataloader):
#      10
#      11             my_count+=1
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in __getitem__(self, index)
#     303
#     304         #Generate.
# --> 305         x = self.create_new_x(pick_num, draft_num)
#     306         y = self.create_new_y(pick_num, draft_num)
#     307         return x, y
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in create_new_x(self, pick_num, draft_num)
#     321         #Fill in collection vector excluding current pick (first half).
#     322         for n in self.drafts_tensor[draft_num, :pick_num, 0]:
# --> 323             x[n] += 1
#     324
#     325         #Fill in pack vector.
#
# KeyboardInterrupt:

# %%
# Reload 0.636
# net = torch.load("draftnet_aug_22_2019.pt")

# %%
# Train the network over several epochs - no momentu, from scratch.
run = 360

# Now leave optimizer out here. 
optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))
#optimizer = optim.ASGD(net.parameters())
#optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.9)

#optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.0)
#optimizer = torch.optim.RMSprop(net.parameters(), lr=0.01, momentum=0.0)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.97)

ep = 0

for run in range(999999):
    
    ep += 1
    print("Epoch:", ep)
    
    # Train1.
    train_net(net, trainloader, 1, optimizer)
    scheduler.step()
    
    # Validation. 
    val_net(net, valloader)
# Out:
# Epoch: 1
# Train Cross-Entropy Loss: 1.075681
# Validation accuracy: 0.6228977777777778  Total picks: 225000
# Epoch: 2
# Train Cross-Entropy Loss: 1.064622
# Validation accuracy: 0.6255777777777778  Total picks: 225000
# Epoch: 3
# Train Cross-Entropy Loss: 1.053039
# Validation accuracy: 0.6281288888888888  Total picks: 225000
# Epoch: 4
# Train Cross-Entropy Loss: 1.044437
# Validation accuracy: 0.6285688888888888  Total picks: 225000
# Epoch: 5
# Train Cross-Entropy Loss: 1.034940
# Validation accuracy: 0.6298  Total picks: 225000
# Epoch: 6
# Train Cross-Entropy Loss: 1.030164
# Validation accuracy: 0.6302622222222222  Total picks: 225000
# Epoch: 7
# Train Cross-Entropy Loss: 1.023588
# Validation accuracy: 0.6302977777777777  Total picks: 225000
# Epoch: 8
# Train Cross-Entropy Loss: 1.019615
# Validation accuracy: 0.6317066666666666  Total picks: 225000
# Epoch: 9
# Train Cross-Entropy Loss: 1.014966
# Validation accuracy: 0.6324933333333334  Total picks: 225000
# Epoch: 10
# Train Cross-Entropy Loss: 1.011653
# Validation accuracy: 0.6334  Total picks: 225000
# Epoch: 11
# Train Cross-Entropy Loss: 1.007529
# Validation accuracy: 0.63516  Total picks: 225000
# Epoch: 12
# Train Cross-Entropy Loss: 1.005565
# Validation accuracy: 0.6337288888888889  Total picks: 225000
# Epoch: 13
# Train Cross-Entropy Loss: 1.003003
# Validation accuracy: 0.6337866666666667  Total picks: 225000
# Epoch: 14
# Train Cross-Entropy Loss: 1.000369
# Validation accuracy: 0.63332  Total picks: 225000
# Epoch: 15
# Train Cross-Entropy Loss: 0.997708
# Validation accuracy: 0.6353022222222222  Total picks: 225000
# Epoch: 16
# Train Cross-Entropy Loss: 0.996145
# Validation accuracy: 0.6347377777777777  Total picks: 225000
# Epoch: 17
# Train Cross-Entropy Loss: 0.993812
# Validation accuracy: 0.6339955555555555  Total picks: 225000
# Epoch: 18
# Train Cross-Entropy Loss: 0.992776
# Validation accuracy: 0.6346133333333334  Total picks: 225000
# Epoch: 19
# Train Cross-Entropy Loss: 0.992154
# Validation accuracy: 0.6358711111111112  Total picks: 225000
# Epoch: 20
# Train Cross-Entropy Loss: 0.989967
# Validation accuracy: 0.6352844444444444  Total picks: 225000
# Epoch: 21
# Train Cross-Entropy Loss: 0.988092
# Validation accuracy: 0.6351022222222222  Total picks: 225000
# Epoch: 22
# Train Cross-Entropy Loss: 0.987622
# Validation accuracy: 0.6359422222222222  Total picks: 225000
# Epoch: 23
# Train Cross-Entropy Loss: 0.985143
# Validation accuracy: 0.6356  Total picks: 225000
# Epoch: 24
# Train Cross-Entropy Loss: 0.984740
# Validation accuracy: 0.6352844444444444  Total picks: 225000
# Epoch: 25
# Train Cross-Entropy Loss: 0.982962
# Validation accuracy: 0.6348222222222222  Total picks: 225000
# Epoch: 26
# Train Cross-Entropy Loss: 0.982101
# Validation accuracy: 0.6359111111111111  Total picks: 225000
# Epoch: 27
# Train Cross-Entropy Loss: 0.982203
# Validation accuracy: 0.6359066666666666  Total picks: 225000
# Epoch: 28
# Train Cross-Entropy Loss: 0.980191
# Validation accuracy: 0.6356622222222222  Total picks: 225000
# Epoch: 29
# Train Cross-Entropy Loss: 0.979032
# Validation accuracy: 0.6353866666666667  Total picks: 225000
# Epoch: 30
# Train Cross-Entropy Loss: 0.978428
# Validation accuracy: 0.6356622222222222  Total picks: 225000
# Epoch: 31
# Train Cross-Entropy Loss: 0.977882
# Validation accuracy: 0.6354844444444444  Total picks: 225000
# Epoch: 32
# Train Cross-Entropy Loss: 0.976206
# Validation accuracy: 0.6356666666666667  Total picks: 225000
# Epoch: 33
# Train Cross-Entropy Loss: 0.976794
# Validation accuracy: 0.6355422222222222  Total picks: 225000
# Epoch: 34
# Train Cross-Entropy Loss: 0.973917
# Validation accuracy: 0.6354  Total picks: 225000
# Epoch: 35
# Train Cross-Entropy Loss: 0.974537
# Validation accuracy: 0.6360133333333333  Total picks: 225000
# Epoch: 36
# Train Cross-Entropy Loss: 0.974492
# Validation accuracy: 0.6370622222222222  Total picks: 225000
# Epoch: 37
# Train Cross-Entropy Loss: 0.973168
# Validation accuracy: 0.6363866666666667  Total picks: 225000
# Epoch: 38
# Train Cross-Entropy Loss: 0.971945
# Validation accuracy: 0.6361955555555555  Total picks: 225000
# Epoch: 39
# Train Cross-Entropy Loss: 0.972556
# Validation accuracy: 0.6361822222222222  Total picks: 225000
# Epoch: 40
# Train Cross-Entropy Loss: 0.972053
# Validation accuracy: 0.6349111111111111  Total picks: 225000
# Epoch: 41
# Train Cross-Entropy Loss: 0.970351
# Validation accuracy: 0.6363688888888889  Total picks: 225000
# Epoch: 42
# Train Cross-Entropy Loss: 0.970221
# Validation accuracy: 0.6355555555555555  Total picks: 225000
# Epoch: 43
# Train Cross-Entropy Loss: 0.969978
# Validation accuracy: 0.6367866666666666  Total picks: 225000
# Epoch: 44
# Train Cross-Entropy Loss: 0.968536
# Validation accuracy: 0.6372533333333333  Total picks: 225000
# Epoch: 45
# Train Cross-Entropy Loss: 0.968983
# Validation accuracy: 0.6365155555555555  Total picks: 225000
# Epoch: 46
# Train Cross-Entropy Loss: 0.968077
# Validation accuracy: 0.6371022222222222  Total picks: 225000
# Epoch: 47
# Train Cross-Entropy Loss: 0.967508
# Validation accuracy: 0.6366622222222222  Total picks: 225000
# Epoch: 48
# Train Cross-Entropy Loss: 0.966723
# Validation accuracy: 0.6366444444444445  Total picks: 225000
# Epoch: 49
# Train Cross-Entropy Loss: 0.967305
# Validation accuracy: 0.6371688888888889  Total picks: 225000
# Epoch: 50
# Train Cross-Entropy Loss: 0.965638
# Validation accuracy: 0.63792  Total picks: 225000
# Epoch: 51
# Train Cross-Entropy Loss: 0.965879
# Validation accuracy: 0.6367244444444444  Total picks: 225000
# Epoch: 52
# Train Cross-Entropy Loss: 0.965145
# Validation accuracy: 0.6374755555555556  Total picks: 225000
# Epoch: 53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-1cba9468ed2a> in <module>()
#      20
#      21     # Train1.
# ---> 22     train_net(net, trainloader, 1, optimizer)
#      23     scheduler.step()
#      24
#
# <ipython-input-52-6b860402cc92> in train_net(net, dataloader, num_epoch, optimizer)
#       7         #Loop over x,y for each dataset.
#       8         running_loss = 0
# ----> 9         for i, data in enumerate(dataloader):
#      10
#      11             my_count+=1
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in __getitem__(self, index)
#     303
#     304         #Generate.
# --> 305         x = self.create_new_x(pick_num, draft_num)
#     306         y = self.create_new_y(pick_num, draft_num)
#     307         return x, y
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in create_new_x(self, pick_num, draft_num)
#     321         #Fill in collection vector excluding current pick (first half).
#     322         for n in self.drafts_tensor[draft_num, :pick_num, 0]:
# --> 323             x[n] += 1
#     324
#     325         #Fill in pack vector.
#
# KeyboardInterrupt:

# %%
#torch.save(net, "draftnet_aug_23_2019.pt")
# Out:
# /home/dan/anaconda3/envs/keras/lib/python3.6/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type DraftNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
# Train the network over several epochs - no momentu, from scratch.
run = 53

# Now leave optimizer out here. 
#optimizer = optim.Adam(net.parameters(), lr=0.0001, betas=(0.9, 0.999)) #Good
#optimizer = optim.ASGD(net.parameters())
optimizer = torch.optim.SGD(net.parameters(), lr=0.00001, momentum=0.0)

#optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.0)
#optimizer = torch.optim.RMSprop(net.parameters(), lr=0.01, momentum=0.0)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.985)

ep = 685

for run in range(999999):
    
    ep += 1
    print("Epoch:", ep)
    
    # Train1.
    train_net(net, trainloader, 1, optimizer)
    scheduler.step()
    
    # Validation. 
    val_net(net, valloader)
# Out:
# Epoch: 686
# Train Cross-Entropy Loss: 0.929028
# Validation accuracy: 0.64008  Total picks: 225000
# Epoch: 687
# Train Cross-Entropy Loss: 0.927985
# Validation accuracy: 0.6399111111111111  Total picks: 225000
# Epoch: 688
# Train Cross-Entropy Loss: 0.928684
# Validation accuracy: 0.64028  Total picks: 225000
# Epoch: 689
# Train Cross-Entropy Loss: 0.929169
# Validation accuracy: 0.6401911111111112  Total picks: 225000
# Epoch: 690
# Train Cross-Entropy Loss: 0.928532
# Validation accuracy: 0.6399688888888889  Total picks: 225000
# Epoch: 691
# Train Cross-Entropy Loss: 0.928613
# Validation accuracy: 0.6402622222222222  Total picks: 225000
# Epoch: 692
# Train Cross-Entropy Loss: 0.930046
# Validation accuracy: 0.6401422222222222  Total picks: 225000
# Epoch: 693
# Train Cross-Entropy Loss: 0.928789
# Validation accuracy: 0.6403244444444445  Total picks: 225000
# Epoch: 694
# Train Cross-Entropy Loss: 0.929501
# Validation accuracy: 0.6400222222222223  Total picks: 225000
# Epoch: 695
# Train Cross-Entropy Loss: 0.928686
# Validation accuracy: 0.6404622222222223  Total picks: 225000
# Epoch: 696
# Train Cross-Entropy Loss: 0.928118
# Validation accuracy: 0.6400133333333333  Total picks: 225000
# Epoch: 697
# Train Cross-Entropy Loss: 0.927881
# Validation accuracy: 0.6401555555555556  Total picks: 225000
# Epoch: 698
# Train Cross-Entropy Loss: 0.928886
# Validation accuracy: 0.6401555555555556  Total picks: 225000
# Epoch: 699
# Train Cross-Entropy Loss: 0.928558
# Validation accuracy: 0.6405111111111111  Total picks: 225000
# Epoch: 700
# Train Cross-Entropy Loss: 0.929315
# Validation accuracy: 0.6402266666666667  Total picks: 225000
# Epoch: 701
# Train Cross-Entropy Loss: 0.928258
# Validation accuracy: 0.6398711111111111  Total picks: 225000
# Epoch: 702
# Train Cross-Entropy Loss: 0.928638
# Validation accuracy: 0.6400355555555556  Total picks: 225000
# Epoch: 703
# Train Cross-Entropy Loss: 0.927924
# Validation accuracy: 0.63988  Total picks: 225000
# Epoch: 704
# Train Cross-Entropy Loss: 0.928916
# Validation accuracy: 0.6400444444444444  Total picks: 225000
# Epoch: 705
# Train Cross-Entropy Loss: 0.928965
# Validation accuracy: 0.6402888888888889  Total picks: 225000
# Epoch: 706
# Train Cross-Entropy Loss: 0.928796
# Validation accuracy: 0.6401688888888889  Total picks: 225000
# Epoch: 707
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-5ed6305550e5> in <module>()
#      20
#      21     # Train1.
# ---> 22     train_net(net, trainloader, 1, optimizer)
#      23     scheduler.step()
#      24
#
# <ipython-input-52-6b860402cc92> in train_net(net, dataloader, num_epoch, optimizer)
#       7         #Loop over x,y for each dataset.
#       8         running_loss = 0
# ----> 9         for i, data in enumerate(dataloader):
#      10
#      11             my_count+=1
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/keras/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in __getitem__(self, index)
#     303
#     304         #Generate.
# --> 305         x = self.create_new_x(pick_num, draft_num)
#     306         y = self.create_new_y(pick_num, draft_num)
#     307         return x, y
#
# ~/Desktop/Code/MTG/Dan/draftsimtools/load.py in create_new_x(self, pick_num, draft_num)
#     321         #Fill in collection vector excluding current pick (first half).
#     322         for n in self.drafts_tensor[draft_num, :pick_num, 0]:
# --> 323             x[n] += 1
#     324
#     325         #Fill in pack vector.
#
# KeyboardInterrupt:

# %%
# optimizer = torch.optim.SGD(net.parameters(), lr=0.00001, momentum=0.0)
# # scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.33) # Used for exp 47.
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.8)

# ep = 0

# for run in range(999999):
    
#     ep += 1
#     print("Epoch:", ep)
    
#     # Train1.
#     train_net(net, trainloader, 1, optimizer)
#     scheduler.step()
    
#     # Validation. 
#     val_net(net, valloader)

# %%
#torch.save(net, "draftnet_aug_22_2019_6404.pt")

# %%
0.0001 * 0.985 ** 685
# Out:
# 3.190199854306796e-09
